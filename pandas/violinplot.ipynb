# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df =pd.read_csv('practice.csv')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
plt.figure(figsize=(4,4))
sns.violinplot(x='island',y='body_mass_g', data=df, palette='cool')
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %%
sns.violinplot(x='island',y='body_mass_g', data=df, palette='cool', saturation=0.1,order=['Dream','Torgersen','island'])
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %%
sns.violinplot(x='island', y='body_mass_g', data=df, hue='sex', split=True, fill=False, gap=5, inner='quart')
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %%
sns.violinplot(x='island', y='body_mass_g', data=df, hue='sex', split=True, fill=False, gap=5, inner='point')
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %%
sns.violinplot(x='island', y='body_mass_g', data=df, hue='sex', split=True, fill=False, gap=5, inner='stick')
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %%
plt.figure(figsize=(4,4))
sns.violinplot(x='island', y='body_mass_g', data=df, hue='sex', split=True, fill=False, gap=5, inner='stick')
sns.stripplot(x='island', data=df)
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %%
sns.scatterplot(df)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(4,4))
sns.stripplot(x='bill_depth_mm',y= 'body_mass_g',color='y', data=df, palette='cool', orient='v', size=5, marker='D')
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10640\2886343816.py:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(x='bill_depth_mm',y= 'body_mass_g',color='y', data=df, palette='cool', orient='v', size=5, marker='D')

# %%
sns.boxplot(x='island', y='body_mass_g', data=df, hue='sex')
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %%
# pip install streamlit

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('marks1.csv')
df1 =df.head(5)
f_n=st.selectbox('select the candidate', pd.unique(df['Name']))

st.title('My first app')
st.write('df')
st.write(df.describe())

# st.write('df')
# st.write(df.info())
# st.write('web_app.py')


a= plt.figure(figsize=(4,4))
plt.boxplot(df['Name'])
st.pyplot(a)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'a'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
df =pd.read_csv('marks1.csv')
df

# %%
df=sns.load_dataset('tips')
df.head(1)
# df.tail(1)

# %%
figr = sns.FacetGrid(df)
figr.map(plt.bar, 'total_bill', 'tip')
plt.show()

# %%
figr = sns.FacetGrid(df, col='sex')
figr.map(plt.scatter, 'total_bill', 'tip')
plt.show()

# %%
figr = sns.FacetGrid(df, col='day', hue='sex').add_legend()
figr.map(plt.scatter, 'total_bill', 'tip')
plt.show()

# %%
figr = sns.FacetGrid(df, col='sex', hue='day', palette='cool').add_legend()
figr.map(plt.scatter, 'total_bill', 'tip')

# %%
# pair plots
df.head(1)

# %%
plt.figure(figsize=(4,4))
sns.pairplot(df, vars=['size', 'tip'],hue_order=['Male', 'Female'], y_vars=['tip'],palette='Accent', kind='hist')
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.pairplot(df, vars=['size', 'tip'],hue_order=['Male', 'Female'], y_vars=['tip'],palette='Accent', kind='kid')
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.pairplot(df, vars=['size', 'tip'],hue_order=['Male', 'Female'], y_vars=['tip'],palette='Accent', kind='scatter', markers=['D','<'])
plt.show()

# %%
sns.catplot(x='total_bill', y ='tip', data=df)

# %%
plt.figure(figsize=(4,4))
sns.catplot(y='size', x ='tip', data=df.head(30), hue='sex', palette='Accent', kind='strip')

# %%
sns.catplot(y='size', x ='tip', data=df.head(30), hue='sex', palette='Accent', kind='point')

# %%
sns.catplot(y='size', x ='tip', data=df.head(50), hue='sex', palette='Accent', kind='boxen')

# %%
import streamlit as st

# %%
import mpl_toolkits as mpt
import numpy as np
import matplotlib.pyplot as plt

# %%
x =np.array([1,2,3,4,5,6,7])
y =np.array([3,5,7,8,9,3,9])
z =np.ones(7)

# %%
xsize =np.ones(7)
ysize =np.ones(7)
zsize =np.array([2,3,2,5,2,4,2])

# %%
plt.figure(figsize=(4,4))
fig = plt.figure()
ax = plt.axes(projection ='3d')
#ax.plot3D(x,y,z, marker='D', color='red', mec='k')
ax.scatter3D(x,y,z, c='g')
plt.show()

# %%
plt.figure(figsize=(4,4))
fig = plt.figure()
ax = plt.axes(projection ='3d')
ax.plot3D(x,y,z, marker='D', color='red', mec='k')
plt.show()
