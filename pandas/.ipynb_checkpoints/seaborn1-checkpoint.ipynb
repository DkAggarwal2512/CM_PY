# %% [markdown]
# define objective, understandig data,resourse

# %%
<img src ='1.jpeg', height= 200, width= 150>
# Out:
#   Cell In[1], line 1
#     <img src ='1.jpeg', height= 200, width= 150>
#     ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib as plt

# %%
df =sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df =pd.read_csv('practice.csv')
df.head(1)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
#
#    body_mass_g   sex
# 0       3750.0  Male

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.dropna()
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
df['bill_length_mm']
# Out:
# 0      39.1
# 1      39.5
# 2      40.3
# 3       NaN
# 4      36.7
#        ...
# 339     NaN
# 340    46.8
# 341    50.4
# 342    45.2
# 343    49.9
# Name: bill_length_mm, Length: 344, dtype: float64

# %%
sns.distplot(df['bill_length_mm'])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_14448\1092832377.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bill_length_mm'])
# <Axes: xlabel='bill_length_mm', ylabel='Density'>

# %%
sns.displot(df['bill_length_mm'],rug=True, color='y')

# %%
#plt.figure(figsize=(4,5))
sns.histplot(df['bill_length_mm'], bins=[30,40,50,60])
#plt.savefig('practice.png')
# plt.show()
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
sns.displot(df['bill_length_mm'], bins=[30,40,50,60])

# %%
x = np.random.randint(30,99,155)
x
# Out:
# array([59, 94, 84, 55, 72, 71, 32, 42, 68, 52, 38, 37, 52, 69, 33, 41, 68,
#        74, 93, 81, 58, 30, 48, 56, 39, 77, 68, 64, 58, 56, 74, 47, 48, 91,
#        81, 97, 88, 47, 63, 48, 51, 50, 42, 36, 31, 90, 41, 39, 42, 72, 55,
#        53, 89, 74, 37, 54, 37, 52, 51, 54, 88, 90, 78, 58, 61, 31, 72, 81,
#        93, 54, 88, 59, 45, 56, 69, 50, 49, 49, 40, 34, 65, 90, 86, 31, 95,
#        75, 39, 78, 86, 38, 78, 80, 64, 77, 33, 75, 88, 78, 84, 59, 92, 37,
#        42, 66, 48, 82, 42, 71, 34, 91, 32, 88, 73, 64, 94, 92, 86, 41, 64,
#        40, 56, 30, 33, 98, 83, 69, 81, 80, 35, 59, 69, 59, 51, 32, 62, 35,
#        62, 50, 57, 86, 96, 90, 94, 36, 69, 96, 95, 98, 71, 82, 75, 97, 55,
#        31, 55])

# %%
x = [59, 94, 84, 55, 72, 71, 32, 42, 68, 52, 38, 37, 52, 69, 33, 41, 68,
       74, 93, 81, 58, 30, 48, 56, 39, 77, 68, 64, 58, 56, 74, 47, 48, 91,
       81, 97, 88, 47, 63, 48, 51, 50, 42, 36, 31, 90, 41, 39, 42, 72, 55,
       53, 89, 74, 37, 54, 37, 52, 51, 54, 88, 90, 78, 58, 61, 31, 72, 81,
       93, 54, 88, 59, 45, 56, 69, 50, 49, 49, 40, 34, 65, 90, 86, 31, 95,
       75, 39, 78, 86, 38, 78, 80, 64, 77, 33, 75, 88, 78, 84, 59, 92, 37,
       42, 66, 48, 82, 42, 71, 34, 91, 32, 88, 73, 64, 94, 92, 86, 41, 64,
       40, 56, 30, 33, 98, 83, 69, 81, 80, 35, 59, 69, 59, 51, 32, 62, 35,
       7, 86, 96, 90, 94, 36, 69, 96, 95, 98, 71, 82, 75, 97, 55,
       31, 55]
sns.distplot(x, bins=[60,70,80,90,120])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_14448\4273304005.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, bins=[60,70,80,90,120])
# <Axes: ylabel='Density'>

# %%
# x= np.random.randint(1,1000,150)
x=[762, 274, 392, 981, 176, 994,  40, 566, 786, 880, 743, 382, 314,
       643, 272,  93, 875, 378, 119, 448, 594, 349, 791, 790, 234, 602,
       919, 479, 268, 291, 665, 935,  56, 146, 511, 972, 869, 901, 331,
        53, 702, 489, 530, 474, 675, 605,  81,  27, 557, 446, 621, 911,
       204, 612, 228, 463, 399, 732, 703, 427, 107, 394, 236, 285, 148,
       535, 496, 679, 366, 611, 861, 413, 331, 808,  84, 121, 267, 709,
       647, 557, 879,  12, 945, 830, 922, 454, 685, 174, 694, 399,  73,
       807, 645, 120, 561, 582, 761, 793, 537, 544, 433, 383,  82, 196,
       370, 650,  70, 161, 874, 156, 884, 374, 813, 289, 686,  51, 434,
       315, 842, 475, 497, 314,  45, 703, 593, 368, 499,  22,  25, 705,
       801,  59, 363, 861,  72, 562, 492, 705, 458, 890, 144, 253, 711,
       606, 701, 127, 290, 729, 462, 613]
sns.distplot(x)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_14448\2391660176.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x)
# <Axes: ylabel='Density'>

# %%
x=[762, 274, 392, 981, 176, 994,  40, 566, 786, 880, 743, 382, 314,
       643, 272,  93, 875, 378, 119, 448, 594, 349, 791, 790, 234, 602,
       919, 479, 268, 291, 665, 935,  56, 146, 511, 972, 869, 901, 331,
        53, 702, 489, 530, 474, 675, 605,  81,  27, 557, 446, 621, 911,
       204, 612, 228, 463, 399, 732, 703, 427, 107, 394, 236, 285, 148,
       535, 496, 679, 366, 611, 861, 413, 331, 808,  84, 121, 267, 709,
       647, 557, 879,  12, 945, 830, 922, 454, 685, 174, 694, 399,  73,
       807, 645, 120, 561, 582, 761, 793, 537, 544, 433, 383,  82, 196,
       370, 650,  70, 161, 874, 156, 884, 374, 813, 289, 686,  51, 434,
       315, 842, 475, 497, 314,  45, 703, 593, 368, 499,  22,  25, 705,
       801,  59, 363, 861,  72, 562, 492, 705, 458, 890, 144, 253, 711,
       606, 701, 127, 290, 729, 462, 613]
sns.displot(x, log_scale=True)

# %%
roll =[1,2,3,4,5]
marks= [89,69,89,82,93]
df1= pd.DataFrame({'RollNo':roll, 'Marks':marks})
sns.lineplot(x = 'Roll No', y = 'Marks',data=df1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[112], line 4
#       2 marks= [89,69,89,82,93]
#       3 df1= pd.DataFrame({'RollNo':roll, 'Marks':marks})
# ----> 4 sns.lineplot(x = 'Roll No', y = 'Marks',data=df1)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\relational.py:618, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     615 errorbar = _deprecate_ci(errorbar, ci)
#     617 variables = _LinePlotter.get_semantics(locals())
# --> 618 p = _LinePlotter(
#     619     data=data, variables=variables,
#     620     estimator=estimator, n_boot=n_boot, seed=seed, errorbar=errorbar,
# ...

# %%
df =pd.read_csv('practice.csv')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df1 =df.head(75)

# %%
sns.lineplot(x='body_mass_g',y='flipper_length_mm',data= df1, hue='island',style='island', markers= ['*','o','>'], dashes=False)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
#sns.set_style('ticks') white, whitegrid, dark,darkgrid,ticks
sns.lineplot(x='body_mass_g',y='flipper_length_mm',data= df1, hue='island',style='island', markers= ['*','o','>'], 
             palette='Pastel2', legend='brief')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.set_style('darkgrid')
sns.barplot(x='island', y='bill_length_mm', data=df,hue='sex',  order=['Dream','Adelie','Gentoo island','Biscoe'], ci=100, saturation=0.75 , capsize=0.5)#palette='copper',
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_14448\3238325045.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 100)` for the same effect.
#
#   sns.barplot(x='island', y='bill_length_mm', data=df,hue='sex',  order=['Dream','Adelie','Gentoo island','Biscoe'], ci=100, saturation=0.75 , capsize=0.5)#palette='copper',
# <Axes: xlabel='island', ylabel='bill_length_mm'>

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.pairplot(df, hue='sex')

# %%
sns.pairplot(df)
