# %%
#BAR CHART

import pandas as pd
import matplotlib.pyplot as plt
df= pd.read_csv('marks1.csv')
df
# Out:
#                     Name  English  Hindi Maths  Science  Social Science
# 0          Smriti Ranjan       85   83.0    93     91.0              94
# 1          Tannu kumari        90   75.0    78     73.0              75
# 2                  Seema       93    NaN    78     89.0              94
# 3          Mukesh Nirmal       92   71.0    72     96.0              75
# 4                  rohit       75   78.0    87     90.0              87
# 5               Ramakant       84   76.0    75     76.0              96
# 6    Vinod Kumar Sharma        75   96.0    74     81.0              71
# 7     Gulshan Kumar Ray        73   74.0   NaN     76.0              85
# 8    Ashutosh Kumar raj        89   70.0     b     97.0              95
# 9             Amit kumar       80   71.0    73     87.0              96
# 10          Astha sachan       77   71.0    77      NaN              72
# 11          Shail Kumari       95   97.0    80     92.0              92
# ...

# %%
plt.plot(df['Name'],df['Social Science'])
plt.show()

# %%
import numpy as np
plt.figure(figsize=(7,3))

x =np.array(['Dehradun','All','KNP'])
y =np.array([17,12,20])
plt.bar(x,y)
plt.show()

# %%
plt.figure(figsize=(7,3))
plt.bar(df['Name'],df['Social Science'])
plt.show()

# %%
#cmykrgbw -cyan, magenta,yellow,black,red,green,blue,white
plt.figure(figsize=(7,3))
color =['r','m','c','g']
plt.title("Student Marks", fontsize=20)
plt.xlabel('Students')
plt.ylabel('Marks', fontsize=15)
plt.bar(df['Name'],df['Social Science'],color=color, width=0.4, align='center')
plt.bar (df['Name'],df['Social Science'], color=color, width=0.4, align='center', edgecolor='y', linewidth=5, linestyle='dashed', label='annual exam result')
plt.bar (df['Name'],df['Social Science'], color=color, width=0.4, align='center', edgecolor='y', linewidth=5, linestyle='dashed', label='annual exam result 2022')


plt.legend()
plt.show()

# %%
plt.figure(figsize=(7,3))
plt.barh(df['Name'], df['Social Science'])
plt.show()

# %%
#Scatter Plot

# %%
x = [2,5,8,9,8]
y = [9,6,8,7,5]
plt.figure(figsize=(7,3))
plt.scatter(x,y)
plt.show()

# %%
x = [2,5,8,9,8]
y = [9,6,8,7,5]
#a =['r','g','b','m','g'color=a,]
s =[130,100,201,90,60]
color=[20,30,50,60,80]
plt.figure(figsize=(7,3))
plt.scatter(x,y, sizes =s, c=color,  alpha=0.5, marker='*' , cmap='plasma')
plt.colorbar()
plt.show()

# %%
x =np.random.randint(30,90,40)
x
# Out:
# array([49, 58, 69, 33, 77, 75, 82, 37, 78, 35, 56, 84, 66, 79, 59, 78, 85,
#        73, 37, 57, 54, 64, 55, 89, 67, 54, 75, 78, 58, 36, 85, 71, 78, 79,
#        60, 83, 56, 67, 58, 81])

# %%
y =np.random.randint(130,190,40)
y
# Out:
# array([173, 150, 143, 178, 183, 173, 145, 169, 171, 162, 149, 181, 173,
#        142, 185, 152, 151, 141, 133, 169, 146, 168, 152, 146, 186, 138,
#        147, 179, 131, 188, 173, 169, 163, 177, 163, 172, 132, 142, 146,
#        162])

# %%
x =[33, 79, 38, 89, 59, 42, 68, 49, 57, 58, 53, 53, 71, 48, 54, 77, 74,
       54, 38, 70, 38, 87, 53, 52, 43, 49, 49, 70, 48, 84, 47, 73, 69, 83,
       85, 77, 75, 47, 63, 54]
y =[170, 149, 136, 158, 151, 188, 174, 184, 148, 169, 182, 150, 130,
       134, 142, 181, 174, 186, 147, 159, 167, 177, 135, 144, 166, 137,
       189, 138, 142, 145, 154, 173, 165, 167, 188, 186, 172, 176, 138,
       143]
plt.figure(figsize=(7,3))
plt.scatter(x,y, color='g')
plt.show()

# %%
from PIL import Image

# %%
plt.savefig('Scat.jpeg')

# %%
# histograms
# pie Chart

# %%
plt.plot(df['Name'], df['Social Science'])

# %% [markdown]
# #Iris dataSet
# <img src ='iris.jpg'>

# %%
df= pd.read_csv('marks1.csv')
df
# Out:
#                     Name  English  Hindi Maths  Science  Social Science
# 0          Smriti Ranjan       85   83.0    93     91.0              94
# 1          Tannu kumari        90   75.0    78     73.0              75
# 2                  Seema       93    NaN    78     89.0              94
# 3          Mukesh Nirmal       92   71.0    72     96.0              75
# 4                  rohit       75   78.0    87     90.0              87
# 5               Ramakant       84   76.0    75     76.0              96
# 6    Vinod Kumar Sharma        75   96.0    74     81.0              71
# 7     Gulshan Kumar Ray        73   74.0   NaN     76.0              85
# 8    Ashutosh Kumar raj        89   70.0     b     97.0              95
# 9             Amit kumar       80   71.0    73     87.0              96
# 10          Astha sachan       77   71.0    77      NaN              72
# 11          Shail Kumari       95   97.0    80     92.0              92
# ...

# %%
plt.bar(df['Name'], df['Social Science'])
plt.savefig('plot.png')

# %%
# Histogram
x =[22,23,23,27,38,34,49,57]
b =[20,30,40,50,60,70,80,90]
plt.figure(figsize=(5,7))
plt.hist(x, bins =b, edgecolor='r')
plt.show()

# %%
value1 =np.random.randint(20,60,100)
value1
# Out:
# array([24, 26, 23, 55, 33, 35, 35, 54, 52, 35, 55, 32, 35, 52, 29, 26, 40,
#        27, 26, 38, 34, 55, 35, 24, 33, 40, 54, 46, 59, 42, 25, 49, 51, 24,
#        54, 49, 41, 45, 44, 23, 41, 36, 25, 54, 30, 33, 33, 30, 42, 34, 21,
#        57, 58, 49, 34, 45, 46, 40, 44, 51, 50, 21, 40, 37, 54, 59, 25, 42,
#        54, 47, 23, 33, 31, 39, 32, 38, 45, 32, 55, 52, 29, 30, 49, 36, 50,
#        32, 27, 30, 56, 39, 58, 25, 47, 57, 34, 59, 58, 49, 37, 35])

# %%
value2= [20, 50, 41, 44, 55, 36, 31, 41, 32, 44, 24, 34, 43, 21, 38, 25, 36,
       38, 34, 33, 35, 58, 37, 50, 20, 42, 46, 28, 56, 56, 28, 37, 21, 21,
       54, 55, 27, 30, 55, 52, 37, 57, 59, 40, 53, 35, 53, 40, 44, 44, 32,
       24, 44, 59, 42, 57, 20, 43, 56, 34, 36, 30, 33, 48, 40, 39, 34, 24,
       38, 26, 33, 52, 37, 55, 56, 38, 48, 59, 28, 22, 50, 37, 32, 24, 36,
       28, 41, 34, 35, 27, 21, 50, 57, 32, 23, 39, 41, 22, 53, 40]

# %%
value2= [20, 50, 41, 44, 55, 36, 31, 41, 32, 44, 24, 34, 43, 21, 38, 25, 36,
       38, 34, 33, 35, 58, 37, 50, 20, 42, 46, 28, 56, 56, 28, 37, 21, 21,
       54, 55, 27, 30, 55, 52, 37, 57, 59, 40, 53, 35, 53, 40, 44, 44, 32,
       24, 44, 59, 42, 57, 20, 43, 56, 34, 36, 30, 33, 48, 40, 39, 34, 24,
       38, 26, 33, 52, 37, 55, 56, 38, 48, 59, 28, 22, 50, 37, 32, 24, 36,
       28, 41, 34, 35, 27, 21, 50, 57, 32, 23, 39, 41, 22, 53, 40]
plt.figure(figsize=(7,3))
b =[20,30,40,50,60,70,80]
plt.hist(value2,bins='auto',color='g', edgecolor='r', align='mid', histtype='step')
plt.hist(value2,bins='auto',color='g', edgecolor='r', align='mid', histtype='stepfilled', orientation='horizontal')
plt.hist(value2,bins=b, edgecolor='r', histtype="bar", rwidth=0.9, log=True, label='Marks')


plt.show()

# %%
x =[45,85,62,85]
y = ['UK','HR','PNJ','JIND']
#c =['g','b','g','r']
ex = [0.1,0.1,0.1,0.2]
plt.pie(x, labels=y, explode=ex, autopct= "%0.1f%%", shadow=True, labeldistance=0.8)
plt.legend(loc =8)
# plt.show()
plt.savefig('pie.png', bbox_inches='tight')
