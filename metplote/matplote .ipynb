# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [78,82,86,89,92]

plt.plot(x,y, color='m')
plt.show()

# %%
plt.plot([2,3,4,5],[56,78,34,56], color="orange")
plt.show()

# %%
x = [1,2,3,4,5]
y = [78,82,86,89,92]
plt.figure(figsize = (4,2))   #figsize (width, height)
plt.plot(x,y, color='m')
plt.show()

# %%
x = [1,2,3,4,5]
y = [78,82,86,89,92]
plt.title('Mahi Saini', fontsize = 15)  #Title
plt.plot(x,y, color='m')
plt.show()

# %%
x = [1,2,3,4,5]
y = [78,82,86,89,92]
#Labels
plt.xlabel('Class', fontsize = 15, color='m')#.set_color('red')
plt.ylabel('Marks', fontsize = 15).set_color('green')
plt.plot(x,y, color='m')
plt.show()

# %%
x = [1,2,3,4,5]
y = [78,82,86,89,92]

a = {'color':'green', 'size':30, 'family':'arial'} 
plt.style.use('Solarize_Light2') #plot style availabe
plt.title('Mahi Ninja Report', fontdict = a, loc='left') #location left , right
plt.plot(x,y, color='m', marker = 'd', linestyle='dashdot')
#markers *,>,o,+,d,p,h,x   #linestyle = -,:,dashdot,none,dashed
plt.grid()
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
x = [1,2,3,4,5]
y = [78,82,86,89,92]
plt.xkcd()
plt.style.use('seaborn-v0_8-colorblind')
plt.title('Mahi Ninja Report',color='red')
plt.plot(x,y, color='m')
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %% [markdown]
# # 9-10-2023 Bar Chart

# %%
import pandas as pd
import matplotlib.pyplot as plt
a = pd.read_csv('matp.csv')
a
# Out:
#        Name  English Hindi Math Science  Social Science
# 0   Manisha     98.0    90   69      85              85
# 1    Seemaj     56.0    81   yh      56              56
# 2  Mukesh..     33.0    74   85      55              56
# 3      Raja     45.0    ef   84      jk              95
# 4    ..Deep     45.0    95   80      75              75
# 5    Sakshi      NaN   NaN  NaN     NaN              52
# 6    Sakshi      NaN   NaN  NaN     NaN              52

# %%
plt.plot(a['Name'],a['Social Science'])
plt.show()
plt.savefig('plot.png')

# %%
import numpy as np
plt.figure(figsize=(7,3))


nsti = np.array(['Dehradun','Allahabad','Kanpur','Patna'])
strength = np.array([18,21,17,20])
plt.bar(nsti,strength)
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
plt.figure(figsize = (7,3))
plt.bar(a['Name'],a['Social Science'])
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
#cmykrgbw - cyan, magenta, yellow, black, red, green, blue, white     #width , align, edgecolor, linewidth, linestyle
color = ['r','m','c','g','b']
plt.title("Student's Marks",fontsize = 20)
plt.xlabel('Students',fontsize = 20 , color='red')
plt.ylabel('Marks',fontsize = 20, color='red')
plt.bar(a['Name'],a['Social Science'], color=color,width = 0.7 ,align = 'center',edgecolor ='y', linewidth= 2, linestyle="dashed", label = 'annual exam result')
plt.legend()
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
plt.bar(a['Name'],a['Social Science'], color=color,width = 0.7 ,align = 'center',edgecolor ='y', linewidth= 2, linestyle="dashed", label = 'annual exam result')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (7,3))
plt.barh(a['Name'],a['Social Science'])
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %% [markdown]
# # Scatter Plot

# %%
x = [2,7,3,6,9]
y = [3,4,5,6,8]
plt.figure(figsize=(7,3))
plt.scatter(x,y)
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
x = np.random.randint(30,90,40)
x
# Out:
# array([48, 58, 78, 89, 53, 44, 45, 53, 60, 47, 75, 70, 58, 70, 75, 38, 72,
#        72, 63, 78, 57, 34, 62, 46, 68, 74, 61, 77, 77, 33, 51, 38, 46, 84,
#        54, 66, 86, 55, 74, 56])

# %%
y =np.random.randint(40,90,40)
y
# Out:
# array([78, 64, 73, 54, 88, 42, 59, 60, 54, 45, 68, 78, 49, 43, 60, 78, 87,
#        56, 87, 67, 47, 54, 79, 66, 59, 79, 58, 59, 73, 63, 84, 73, 80, 80,
#        64, 81, 52, 83, 40, 74])

# %%
x = [78, 48, 35, 33, 77, 67, 56, 40, 84, 83, 74, 55, 56, 57, 35, 47, 55,
       48, 46, 54, 44, 47, 45, 63, 71, 32, 35, 42, 55, 83, 72, 58, 35, 87,
       72, 42, 57, 82, 46, 32]
y = [53, 62, 44, 54, 45, 56, 55, 44, 86, 60, 51, 42, 82, 86, 40, 61, 84,
       76, 80, 74, 85, 83, 84, 57, 61, 70, 81, 70, 83, 48, 74, 47, 77, 40,
       73, 77, 80, 70, 47, 84]
plt.figure(figsize=(7,3))
plt.scatter(x,y)
plt.show()

# %%
x = [2,7,3,6,9]
y = [3,4,5,6,8]
#color = ['r','y','c','g','m']  color=color,, alpha = 0.2
size = [300,600,800,900,400]
color=[34,56,70,47,70]
plt.figure(figsize=(7,3))
plt.scatter(x,y, sizes = size, c= color,marker ='*'  ,cmap='Accent_r')
plt.colorbar()
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
#<img src = 'a.jpg'> Markdowm image

# %% [markdown]
# <img src = 'b.jpg'>

# %%
#Histogram

# %%
x = [22,25,33,27,38,49,57,78,90,69,80]
y = [20,29,40,50,60,70,80,90,100]
plt.figure(figsize =(7,3))
plt.hist(x, bins=y,edgecolor='m')
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
value1 = np.random.randint(20,60,80)
value1
# Out:
# array([41, 49, 32, 54, 57, 45, 56, 44, 21, 55, 29, 20, 43, 58, 22, 51, 42,
#        57, 45, 57, 21, 42, 43, 36, 30, 25, 40, 37, 53, 46, 47, 44, 22, 29,
#        49, 32, 42, 36, 37, 43, 20, 32, 24, 44, 21, 46, 54, 28, 20, 56, 31,
#        53, 53, 44, 33, 32, 36, 32, 47, 20, 31, 22, 41, 39, 47, 54, 28, 21,
#        44, 42, 29, 35, 45, 48, 20, 43, 44, 20, 55, 58])

# %%
value2 =[40, 36, 48, 24, 25, 25, 48, 26, 43, 50, 47, 23, 37, 23, 22, 20, 36,
       34, 52, 39, 32, 38, 53, 27, 46, 24, 28, 29, 23, 38, 32, 45, 49, 31,
       59, 34, 26, 53, 33, 37, 49, 53, 48, 45, 59, 57, 37, 36, 41, 31, 34,
       48, 42, 21, 35, 30, 54, 27, 37, 56, 25, 33, 55, 56, 48, 23, 28, 49,
       37, 33, 33, 28, 29, 21, 40, 23, 58, 31, 28, 57]

# %%
plt.figure(figsize=(7,3))
#b = [20,30,40,50,60] ,bins=b    #align - left, right, mid
plt.hist(value2,edgecolor='m',color='y',align='mid')
plt.show()

# %%
plt.figure(figsize=(7,3))
b = [20,30,40,50,60]     
#histtype='stepfilled','bar','step'  ,orientation='horizontal'
plt.hist(value2,edgecolor='m',bins=b, histtype='bar',rwidth = 0.9, log=True,label='marks')
plt.show()

# %%
#Pie

# %%
x = [45,65,50,75]
y = ['9th Class','10th Class','11th Class','12th Class'] #, radius=1
c = ['r','b','g','m']
ex = [0.0,0.0,0.1,0.0]
plt.pie(x, labels=y , explode = ex, colors=c, autopct = '%0.1f%%',shadow = True, labeldistance = 0.4)
plt.legend(loc = 9)
#plt.show()
plt.savefig('pie.png',bbox_inches='tight')
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
#Box plot& wisker plot

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(4,5))
x = [40,50,60,70,80,90]
plt.boxplot(x)
#plt.show()
plt.savefig('box.png')
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
plt.figure(figsize=(4,5))
x = [40,50,60,70,80,90]
plt.boxplot(x, notch = True)
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
#show oultliers 
plt.figure(figsize=(7,5))
x = [40,50,160,70,80,]
plt.boxplot(x , vert = False, widths=0.3, labels = ["Student's Marks"],patch_artist = True, showmeans = True)
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
import numpy as np 
a = np.random.randint(40,70,50)
a
# Out:
# array([69, 54, 53, 48, 46, 58, 69, 49, 57, 54, 64, 60, 58, 48, 46, 44, 54,
#        58, 66, 48, 63, 53, 52, 51, 64, 49, 49, 58, 45, 56, 40, 66, 57, 50,
#        62, 47, 52, 43, 65, 43, 48, 49, 56, 53, 44, 55, 50, 41, 56, 43])

# %%
b = [63, 65, 63, 53, 64, 59, 55, 62, 56, 46, 59, 62, 56, 67, 64, 65, 55,
       67, 50, 41, 69, 66, 44, 60, 67, 42, 64, 53, 53, 42, 49, 46, 67, 66,
       66, 48, 54, 48, 67, 68, 59, 53, 42, 49, 46, 59, 67, 50, 68, 55]
plt.figure(figsize=(4,2))
plt.boxplot(b, vert = False, boxprops = dict(color = 'r'), capprops = dict(color = 'r'), whiskerprops =dict(color='g'))
plt.show()

# %%
#Seaborn 
import seaborn as sns

# %%
a = sns.load_dataset('titanic')
a
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
a1 = sns.load_dataset('healthexp')
a1
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0
#
# [274 rows x 4 columns]

# %%
#Box Plot
b = [63, 65, 63, 53, 64, 59, 55, 62, 56, 46, 59, 62, 56, 67, 64, 65, 55,
       67, 50, 41, 69, 66, 44, 60, 67, 42, 64, 53, 53, 42, 49, 46, 67, 66,
       66, 48, 54, 48, 67, 68, 59, 53, 42, 49, 46, 59, 67, 50, 68, 55]

b1=[78,56,79,67,80]
b2=[67,78,90,59,89,72,74,92]
x =[b,b1,b2]
plt.figure(figsize=(4,6))
plt.boxplot(x, labels=['Dehradun','Panipat','Patna'])
plt.show()

# %% [markdown]
# #  11-10-2023

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

ages=[67,56,89,78,48,94,85,98,87,89,67,85,78,97,89]

# %%
ages
# Out:
# [67, 56, 89, 78, 48, 94, 85, 98, 87, 89, 67, 85, 78, 97, 89]

# %%
ages=pd.DataFrame(ages)
ages
# Out:
#      0
# 0   67
# 1   56
# 2   89
# 3   78
# 4   48
# 5   94
# 6   85
# 7   98
# 8   87
# 9   89
# 10  67
# 11  85
# 12  78
# 13  97
# 14  89

# %%
ages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       15 non-null     int64
# dtypes: int64(1)
# memory usage: 252.0 bytes

# %%
ages.describe()
# Out:
#                0
# count  15.000000
# mean   80.466667
# std    14.865428
# min    48.000000
# 25%    72.500000
# 50%    85.000000
# 75%    89.000000
# max    98.000000

# %%
plt.boxplot(ages)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

x = np.random.randint(0,10,6)
y = np.random.randint(20,100,6)

# %%
x
# Out:
# array([1, 7, 3, 8, 3, 9])

# %%
y
# Out:
# array([29, 28, 62, 41, 54, 55])

# %%
x = [1, 7, 3, 8, 3, 9]
y = [29, 28, 62, 41, 54, 55]
plt.figure(figsize=(4,3))
plt.subplot(1,1,1)
plt.plot(x,y)
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.8.0
