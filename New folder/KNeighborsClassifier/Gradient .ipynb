# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv('sata.csv')

# %%
df
# Out:
#       Age   Income
# 0     NaN      NaN
# 1    59.0  46408.0
# 2     NaN      NaN
# 3    45.0  30627.0
# 4     NaN      NaN
# ..    ...      ...
# 103  47.0  60220.0
# 104   NaN      NaN
# 105  42.0  52194.0
# 106   NaN      NaN
# 107  38.0  36759.0
#
# [108 rows x 2 columns]

# %%
df.sample()
# Out:
#      Age   Income
# 87  55.0  49446.0

# %%
df.dropna()
# Out:
#       Age   Income
# 1    59.0  46408.0
# 3    45.0  30627.0
# 5    48.0  53542.0
# 7    33.0  62705.0
# 9    51.0  41872.0
# 11   26.0  48912.0
# 13   33.0  36097.0
# 15   42.0  63468.0
# 17   28.0  52373.0
# 19   32.0  29946.0
# 21   50.0  58834.0
# 23   42.0  34907.0
# 25   41.0  27113.0
# 27   45.0  35318.0
# 29   31.0  26554.0
# 31   26.0  68712.0
# 33   51.0  68111.0
# 35   49.0  68367.0
# 37   33.0  54271.0
# 39   40.0  53227.0
# 41   41.0  54734.0
# 43   27.0  45772.0
# 45   42.0  29118.0
# 47   39.0  26495.0
# 49   25.0  64282.0
# 51   40.0  66052.0
# 53   31.0  25534.0
# 55   39.0  36950.0
# 57   40.0  65014.0
# 59   58.0  27700.0
# 61   50.0  27462.0
# 63   28.0  68693.0
# 65   36.0  61818.0
# 67   58.0  47111.0
# 69   47.0  28864.0
# 71   37.0  45202.0
# 73   57.0  41994.0
# 75   26.0  29252.0
# 77   34.0  36098.0
# 79   34.0  30969.0
# 81   32.0  61250.0
# 83   48.0  66954.0
# 85   44.0  36662.0
# 87   55.0  49446.0
# 89   56.0  39934.0
# 91   51.0  25613.0
# 93   47.0  59957.0
# 95   46.0  49326.0
# 97   49.0  25980.0
# 99   56.0  35047.0
# 101  43.0  30050.0
# 103  47.0  60220.0
# 105  42.0  52194.0
# 107  38.0  36759.0

# %%
df.sample()
# Out:
#      Age   Income
# 29  31.0  26554.0

# %%
def gradie(x,y):
    m_curr = c_curr = 0
    rate = 0.01
    n = len(x)
    plt.scatter(x, y, marker='*', linewidth=2)

    for i in range(10000):
        y_pred = m_curr * x + c_curr
        plt.plot(x, y_pred, color='g')
        md = -(2/n) * sum(x * (y - y_pred))
        cd = -(2/n) * sum(y - y_pred)
        m_curr = m_curr - rate * md
        c_curr = c_curr - rate * cd

# %%
# x = [1, 2, 3, 4, 5]
# y = [2, 3, 2.5, 4, 3.5]
x= ['Age']
y=['Income']
gradie(x, y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 5
#       3 x= ['Age']
#       4 y=['Income']
# ----> 5 gradie(x, y)
#
# Cell In[32], line 8, in gradie(x, y)
#       5 plt.scatter(x, y, marker='*', linewidth=2)
#       7 for i in range(10000):
# ----> 8     y_pred = m_curr * x + c_curr
#       9     plt.plot(x, y_pred, color='g')
#      10     md = -(2/n) * sum(x * (y - y_pred))
#
# TypeError: can only concatenate list (not "int") to list

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 klkll
#
# NameError: name 'klkll' is not defined
