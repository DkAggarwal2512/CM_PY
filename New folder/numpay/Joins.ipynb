# %%
import pandas as pd

# %%
a = pd.read_csv('details.csv')
a
# Out:
#                     Name                              Mail   Location  Maths
# 0          Smriti Ranjan          smritiranjan65@gmail.com      Patna     93
# 1          Tannu kumari            tkumari930451@gmail.com      Patna     78
# 2                  Seema         dksainiaggarwal@gmail.com   Dehradun     78
# 3          Mukesh Nirmal         nirmalmukesh200@gmail.com   Dehradun     72
# 4                  rohit                               NaN        NaN     87
# 5               Ramakant     ramakantprajapati11@gmail.com   Dehradun     75
# 6    Vinod Kumar Sharma        vinodsharma740860@gmail.com     Kanpur     74
# 7     Gulshan Kumar Ray            raygulshan960@gmail.com   Dehradun     83
# 8    Ashutosh Kumar raj           ashutoshraj822@gmail.com      Patna     89
# 9             Amit kumar          amitpatel8340s@gmail.com      Patna     73
# 10          Astha sachan           asthasachan96@gmail.com     Kanpur     77
# ...

# %%
b = pd.read_csv('marks.csv')
b
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science
# 0          Smriti Ranjan       85     83     93       91              94
# 1          Tannu kumari        90     75     78       73              75
# 2                  Seema       93     75     78       89              94
# 3          Mukesh Nirmal       92     71     72       96              75
# 4                  rohit       75     78     87       90              87
# 5               Ramakant       84     76     75       76              96
# 6    Vinod Kumar Sharma        75     94     74       81              71
# 7     Gulshan Kumar Ray        73     74     83       76              94
# 8    Ashutosh Kumar raj        89     70     89       97              81
# 9             Amit kumar       80     71     73       87              96
# 10          Astha sachan       77     71     77       93              72
# 11          Shail Kumari       95     97     80       92              92
# ...

# %%
pd.merge(a,b)
# Out:
#                     Name                              Mail   Location  Maths  \
# 0          Smriti Ranjan          smritiranjan65@gmail.com      Patna     93
# 1          Tannu kumari            tkumari930451@gmail.com      Patna     78
# 2                  Seema         dksainiaggarwal@gmail.com   Dehradun     78
# 3          Mukesh Nirmal         nirmalmukesh200@gmail.com   Dehradun     72
# 4                  rohit                               NaN        NaN     87
# 5               Ramakant     ramakantprajapati11@gmail.com   Dehradun     75
# 6    Vinod Kumar Sharma        vinodsharma740860@gmail.com     Kanpur     74
# 7     Gulshan Kumar Ray            raygulshan960@gmail.com   Dehradun     83
# 8    Ashutosh Kumar raj           ashutoshraj822@gmail.com      Patna     89
# 9             Amit kumar          amitpatel8340s@gmail.com      Patna     73
# 10          Astha sachan           asthasachan96@gmail.com     Kanpur     77
# ...

# %%
pd.merge(a,b, on ='Name')
# Out:
#                     Name                              Mail   Location  \
# 0          Smriti Ranjan          smritiranjan65@gmail.com      Patna
# 1          Tannu kumari            tkumari930451@gmail.com      Patna
# 2                  Seema         dksainiaggarwal@gmail.com   Dehradun
# 3          Mukesh Nirmal         nirmalmukesh200@gmail.com   Dehradun
# 4                  rohit                               NaN        NaN
# 5               Ramakant     ramakantprajapati11@gmail.com   Dehradun
# 6    Vinod Kumar Sharma        vinodsharma740860@gmail.com     Kanpur
# 7     Gulshan Kumar Ray            raygulshan960@gmail.com   Dehradun
# 8    Ashutosh Kumar raj           ashutoshraj822@gmail.com      Patna
# 9             Amit kumar          amitpatel8340s@gmail.com      Patna
# 10          Astha sachan           asthasachan96@gmail.com     Kanpur
# 11          Shail Kumari           shailverma945@gmail.com     Kanpur
# ...

# %%
pd.merge(a,b,on ='Maths')
# Out:
#                   Name_x                              Mail   Location  Maths  \
# 0          Smriti Ranjan          smritiranjan65@gmail.com      Patna     93
# 1          Tannu kumari            tkumari930451@gmail.com      Patna     78
# 2          Tannu kumari            tkumari930451@gmail.com      Patna     78
# 3                  Seema         dksainiaggarwal@gmail.com   Dehradun     78
# 4                  Seema         dksainiaggarwal@gmail.com   Dehradun     78
# 5          Mukesh Nirmal         nirmalmukesh200@gmail.com   Dehradun     72
# 6                  rohit                               NaN        NaN     87
# 7               Ramakant     ramakantprajapati11@gmail.com   Dehradun     75
# 8    Vinod Kumar Sharma        vinodsharma740860@gmail.com     Kanpur     74
# 9    Vinod Kumar Sharma        vinodsharma740860@gmail.com     Kanpur     74
# 10                Trapti          traptishakya21@gmail.com  Allahabad     74
# ...

# %%
pd.merge(a,b, how='inner')
# Out:
#                     Name                              Mail   Location  Maths  \
# 0          Smriti Ranjan          smritiranjan65@gmail.com      Patna     93
# 1          Tannu kumari            tkumari930451@gmail.com      Patna     78
# 2                  Seema         dksainiaggarwal@gmail.com   Dehradun     78
# 3          Mukesh Nirmal         nirmalmukesh200@gmail.com   Dehradun     72
# 4                  rohit                               NaN        NaN     87
# 5               Ramakant     ramakantprajapati11@gmail.com   Dehradun     75
# 6    Vinod Kumar Sharma        vinodsharma740860@gmail.com     Kanpur     74
# 7     Gulshan Kumar Ray            raygulshan960@gmail.com   Dehradun     83
# 8    Ashutosh Kumar raj           ashutoshraj822@gmail.com      Patna     89
# 9             Amit kumar          amitpatel8340s@gmail.com      Patna     73
# 10          Astha sachan           asthasachan96@gmail.com     Kanpur     77
# ...

# %%
pd.merge(a,b, how='left')
# Out:
#                     Name                              Mail   Location  Maths  \
# 0          Smriti Ranjan          smritiranjan65@gmail.com      Patna     93
# 1          Tannu kumari            tkumari930451@gmail.com      Patna     78
# 2                  Seema         dksainiaggarwal@gmail.com   Dehradun     78
# 3          Mukesh Nirmal         nirmalmukesh200@gmail.com   Dehradun     72
# 4                  rohit                               NaN        NaN     87
# 5               Ramakant     ramakantprajapati11@gmail.com   Dehradun     75
# 6    Vinod Kumar Sharma        vinodsharma740860@gmail.com     Kanpur     74
# 7     Gulshan Kumar Ray            raygulshan960@gmail.com   Dehradun     83
# 8    Ashutosh Kumar raj           ashutoshraj822@gmail.com      Patna     89
# 9             Amit kumar          amitpatel8340s@gmail.com      Patna     73
# 10          Astha sachan           asthasachan96@gmail.com     Kanpur     77
# ...

# %%
pd.merge(a,b, how='right')
# Out:
#                     Name                              Mail   Location  Maths  \
# 0          Smriti Ranjan          smritiranjan65@gmail.com      Patna     93
# 1          Tannu kumari            tkumari930451@gmail.com      Patna     78
# 2                  Seema         dksainiaggarwal@gmail.com   Dehradun     78
# 3          Mukesh Nirmal         nirmalmukesh200@gmail.com   Dehradun     72
# 4                  rohit                               NaN        NaN     87
# 5               Ramakant     ramakantprajapati11@gmail.com   Dehradun     75
# 6    Vinod Kumar Sharma        vinodsharma740860@gmail.com     Kanpur     74
# 7     Gulshan Kumar Ray            raygulshan960@gmail.com   Dehradun     83
# 8    Ashutosh Kumar raj           ashutoshraj822@gmail.com      Patna     89
# 9             Amit kumar          amitpatel8340s@gmail.com      Patna     73
# 10          Astha sachan           asthasachan96@gmail.com     Kanpur     77
# ...

# %%
pd.merge(a,b, how='outer', indicator= True)
# Out:
#                     Name                              Mail   Location  Maths  \
# 0          Smriti Ranjan          smritiranjan65@gmail.com      Patna     93
# 1          Tannu kumari            tkumari930451@gmail.com      Patna     78
# 2                  Seema         dksainiaggarwal@gmail.com   Dehradun     78
# 3          Mukesh Nirmal         nirmalmukesh200@gmail.com   Dehradun     72
# 4                  rohit                               NaN        NaN     87
# 5               Ramakant     ramakantprajapati11@gmail.com   Dehradun     75
# 6    Vinod Kumar Sharma        vinodsharma740860@gmail.com     Kanpur     74
# 7     Gulshan Kumar Ray            raygulshan960@gmail.com   Dehradun     83
# 8    Ashutosh Kumar raj           ashutoshraj822@gmail.com      Patna     89
# 9             Amit kumar          amitpatel8340s@gmail.com      Patna     73
# 10          Astha sachan           asthasachan96@gmail.com     Kanpur     77
# ...

# %%
pd.concat([a,b])
# Out:
#                     Name                              Mail   Location  Maths  \
# 0          Smriti Ranjan          smritiranjan65@gmail.com      Patna     93
# 1          Tannu kumari            tkumari930451@gmail.com      Patna     78
# 2                  Seema         dksainiaggarwal@gmail.com   Dehradun     78
# 3          Mukesh Nirmal         nirmalmukesh200@gmail.com   Dehradun     72
# 4                  rohit                               NaN        NaN     87
# 5               Ramakant     ramakantprajapati11@gmail.com   Dehradun     75
# 6    Vinod Kumar Sharma        vinodsharma740860@gmail.com     Kanpur     74
# 7     Gulshan Kumar Ray            raygulshan960@gmail.com   Dehradun     83
# 8    Ashutosh Kumar raj           ashutoshraj822@gmail.com      Patna     89
# 9             Amit kumar          amitpatel8340s@gmail.com      Patna     73
# 10          Astha sachan           asthasachan96@gmail.com     Kanpur     77
# ...

# %%
pd.concat([a,b], axis= 1 ,join ='inner')
# Out:
#                     Name                              Mail   Location  Maths  \
# 0          Smriti Ranjan          smritiranjan65@gmail.com      Patna     93
# 1          Tannu kumari            tkumari930451@gmail.com      Patna     78
# 2                  Seema         dksainiaggarwal@gmail.com   Dehradun     78
# 3          Mukesh Nirmal         nirmalmukesh200@gmail.com   Dehradun     72
# 4                  rohit                               NaN        NaN     87
# 5               Ramakant     ramakantprajapati11@gmail.com   Dehradun     75
# 6    Vinod Kumar Sharma        vinodsharma740860@gmail.com     Kanpur     74
# 7     Gulshan Kumar Ray            raygulshan960@gmail.com   Dehradun     83
# 8    Ashutosh Kumar raj           ashutoshraj822@gmail.com      Patna     89
# 9             Amit kumar          amitpatel8340s@gmail.com      Patna     73
# 10          Astha sachan           asthasachan96@gmail.com     Kanpur     77
# ...

# %%
pd.concat([a,b], axis= 1 ,join ='inner', keys=['Details','Marks'])
# Out:
#                  Details                                                     \
#                     Name                              Mail   Location Maths
# 0          Smriti Ranjan          smritiranjan65@gmail.com      Patna    93
# 1          Tannu kumari            tkumari930451@gmail.com      Patna    78
# 2                  Seema         dksainiaggarwal@gmail.com   Dehradun    78
# 3          Mukesh Nirmal         nirmalmukesh200@gmail.com   Dehradun    72
# 4                  rohit                               NaN        NaN    87
# 5               Ramakant     ramakantprajapati11@gmail.com   Dehradun    75
# 6    Vinod Kumar Sharma        vinodsharma740860@gmail.com     Kanpur    74
# 7     Gulshan Kumar Ray            raygulshan960@gmail.com   Dehradun    83
# 8    Ashutosh Kumar raj           ashutoshraj822@gmail.com      Patna    89
# 9             Amit kumar          amitpatel8340s@gmail.com      Patna    73
# ...

# %%
pd.concat([a,b], axis= 0 ,join ='inner', keys=['Details','Marks'])
# Out:
#                             Name  Maths
# Details 0          Smriti Ranjan     93
#         1          Tannu kumari      78
#         2                  Seema     78
#         3          Mukesh Nirmal     72
#         4                  rohit     87
#         5               Ramakant     75
#         6    Vinod Kumar Sharma      74
#         7     Gulshan Kumar Ray      83
#         8    Ashutosh Kumar raj      89
#         9             Amit kumar     73
#         10          Astha sachan     77
#         11          Shail Kumari     80
#         12  Vaishnavi Kesherwani     88
#         13             Rahul Rai     76
#         14                Trapti     74
#         15       Annapurna Rawat     79
# Marks   0          Smriti Ranjan     93
#         1          Tannu kumari      78
#         2                  Seema     78
#         3          Mukesh Nirmal     72
#         4                  rohit     87
#         5               Ramakant     75
# ...

# %%
a1 = a.groupby('Name')
a1

# %%
a1.get_group('Trapti')
# Out:
#       Name                      Mail   Location  Maths
# 14  Trapti  traptishakya21@gmail.com  Allahabad     74

# %%
for x , y in a1:
    print(x)
    print(y)
# Out:
# Amit kumar
#          Name                      Mail Location  Maths
# 9  Amit kumar  amitpatel8340s@gmail.com    Patna     73
# Annapurna Rawat
#                Name                     Mail   Location  Maths
# 15  Annapurna Rawat  nainarawat003@gmail.com  Allahabad     79
# Ashutosh Kumar raj
#                   Name                      Mail Location  Maths
# 8  Ashutosh Kumar raj   ashutoshraj822@gmail.com    Patna     89
# Astha sachan
#             Name                     Mail Location  Maths
# 10  Astha sachan  asthasachan96@gmail.com   Kanpur     77
# Gulshan Kumar Ray
#                  Name                     Mail  Location  Maths
# 7  Gulshan Kumar Ray   raygulshan960@gmail.com  Dehradun     83
# Mukesh Nirmal
#             Name                       Mail  Location  Maths
# 3  Mukesh Nirmal  nirmalmukesh200@gmail.com  Dehradun     72
# Rahul Rai
#          Name                     Mail  Location  Maths
# 13  Rahul Rai  rahul.rai8997@gmail.com  Dehradun     76
# Ramakant
# ...

# %%
a2 = a.groupby('Maths')
a2

# %%
a2.get_group(80)
# Out:
#             Name                     Mail Location  Maths
# 11  Shail Kumari  shailverma945@gmail.com   Kanpur     80

# %%
for x , y in a2:
    print(x)
    print(y)
# Out:
# 72
#             Name                       Mail  Location  Maths
# 3  Mukesh Nirmal  nirmalmukesh200@gmail.com  Dehradun     72
# 73
#          Name                      Mail Location  Maths
# 9  Amit kumar  amitpatel8340s@gmail.com    Patna     73
# 74
#                    Name                         Mail   Location  Maths
# 6   Vinod Kumar Sharma   vinodsharma740860@gmail.com     Kanpur     74
# 14               Trapti     traptishakya21@gmail.com  Allahabad     74
# 75
#        Name                           Mail  Location  Maths
# 5  Ramakant  ramakantprajapati11@gmail.com  Dehradun     75
# 76
#          Name                     Mail  Location  Maths
# 13  Rahul Rai  rahul.rai8997@gmail.com  Dehradun     76
# 77
#             Name                     Mail Location  Maths
# 10  Astha sachan  asthasachan96@gmail.com   Kanpur     77
# 78
#             Name                       Mail  Location  Maths
# 1  Tannu kumari     tkumari930451@gmail.com     Patna     78
# ...

# %%
a.join(b,rsuffix='_1')
# Out:
#                     Name                              Mail   Location  Maths  \
# 0          Smriti Ranjan          smritiranjan65@gmail.com      Patna     93
# 1          Tannu kumari            tkumari930451@gmail.com      Patna     78
# 2                  Seema         dksainiaggarwal@gmail.com   Dehradun     78
# 3          Mukesh Nirmal         nirmalmukesh200@gmail.com   Dehradun     72
# 4                  rohit                               NaN        NaN     87
# 5               Ramakant     ramakantprajapati11@gmail.com   Dehradun     75
# 6    Vinod Kumar Sharma        vinodsharma740860@gmail.com     Kanpur     74
# 7     Gulshan Kumar Ray            raygulshan960@gmail.com   Dehradun     83
# 8    Ashutosh Kumar raj           ashutoshraj822@gmail.com      Patna     89
# 9             Amit kumar          amitpatel8340s@gmail.com      Patna     73
# 10          Astha sachan           asthasachan96@gmail.com     Kanpur     77
# ...

# %%
a.join(b,rsuffix='_1')
