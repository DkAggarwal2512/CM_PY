# %% [markdown]
# Logistic Regression-Iris Dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#
df=pd.read_csv('Iris.csv')
df.head(2)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa

# %%
df1=df.drop('Species',axis='columns')

# %%
df1.head(2)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0   1            5.1           3.5            1.4           0.2
# 1   2            4.9           3.0            1.4           0.2

# %%
plt.figure(figsize=(1,1))
sns.pairplot(df,hue='Species')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
#labels
setosa:1
virginica:2
versicolor:3

# %%
df['Species'].replace({'Iris-setosa':'1','Iris-virginica':'2','Iris-versicolor':'3'}, inplace=True)

# %%
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Species
# 0   1            5.1           3.5            1.4           0.2       1
# 1   2            4.9           3.0            1.4           0.2       1
# 2   3            4.7           3.2            1.3           0.2       1
# 3   4            4.6           3.1            1.5           0.2       1
# 4   5            5.0           3.6            1.4           0.2       1

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
,df['Species'])

# %%
x_train.shape
# Out:
# (112, 4)

# %%
x_test.shape
# Out:
# (38, 4)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array(['2', '1', '2', '2', '1', '2', '2', '1', '3', '2', '2', '3', '1',
#        '1', '3', '3', '3', '3', '1', '2', '3', '2', '2', '3', '1', '1',
#        '1', '2', '2', '2', '3', '2', '1', '1', '1', '2', '2', '2'],
#       dtype=object)

# %%
y_test
# Out:
# 124    2
# 44     1
# 143    2
# 101    2
# 36     1
# 122    2
# 123    2
# 7      1
# 69     3
# 128    2
# 116    2
# 88     3
# 2      1
# 4      1
# 51     3
# 94     3
# 52     3
# 98     3
# 6      1
# 115    2
# 86     3
# 112    2
# 111    2
# 58     3
# 38     1
# 11     1
# 24     1
# 118    2
# 147    2
# 114    2
# 59     3
# 70     3
# 37     1
# 34     1
# 29     1
# 83     3
# 129    2
# 113    2
# Name: Species, dtype: object

# %%
model.score(x_test,y_test)
# Out:
# 0.9473684210526315

# %%
model.coef_
# Out:
# array([[-0.40264931,  0.83601106, -2.35686482, -0.92875666],
#        [-0.14077544, -0.42422855,  2.53976973,  1.77237936],
#        [ 0.54342475, -0.41178251, -0.18290491, -0.84362269]])

# %%
model.intercept_
# Out:
# array([  9.32736794, -11.32197647,   1.99460854])

# %%
model.score(x_test,y_test)
# Out:
# 0.9473684210526315

# %%
#sigmoid function

# %%
a='SepalLengthCm'	
b='SepalWidthCm'
c='PetalLengthCm'
d='PetalWidthCm'

# %%
def sig(x):
    import math
    return1/(1+math.e**(-x))

# %%
def pred_f(a,b,c,d):

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import ydata_profiling
from ydata_profiling import ProfileReport

# %% [markdown]
# EDA

# %% [markdown]
# Data Mining

# %%
import pandas as pd
df = pd.read_csv('employees.csv')

# %%
df.head(6)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 5     Dennis    Male  4/18/1987         1:35 AM  115163   10.125
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services
# 5             False            Legal

# %%
df.sample(5)
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 469    Stephen    Male   5/9/2015         7:07 PM  141958    9.078
# 23         NaN    Male  6/14/2012         4:19 PM  125792    5.042
# 522  Catherine  Female  8/31/2013         7:24 PM   58047   14.858
# 739     Carlos    Male  1/25/1981        10:00 AM  138598   14.737
# 85      Jeremy    Male   2/1/2008         8:50 AM  100238    3.887
#
#     Senior Management             Team
# 469              True            Legal
# 23                NaN              NaN
# 522              True     Distribution
# 739             False            Sales
# 85               True  Client Services

# %%
df.isnull().any()
# Out:
# First Name            True
# Gender                True
# Start Date           False
# Last Login Time      False
# Salary               False
# Bonus %              False
# Senior Management     True
# Team                  True
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#               Salary      Bonus %
# count    1000.000000  1000.000000
# mean    90662.181000    10.207555
# std     32923.693342     5.528481
# min     35013.000000     1.015000
# 25%     62613.000000     5.401750
# 50%     90428.000000     9.838500
# 75%    118740.250000    14.838000
# max    149908.000000    19.944000

# %%
df['First Name']= df['First Name'].fillna('Gulshan ')

# %%
df['First Name'].sample(20)
# Out:
# 862      Ronald
# 295       Jesse
# 584        Jack
# 943       Wayne
# 757    Benjamin
# 801        Ryan
# 114      Ashley
# 392       Ralph
# 969       Linda
# 649        Ruth
# 330       Randy
# 993        Tina
# 374          NA
# 653       Debra
# 759        Ruth
# 906     Frances
# 313        Judy
# 738      Joseph
# 375     Gregory
# 87        Annie
# Name: First Name, dtype: object

# %%
df['First Name']= df['First Name'].replace(to_replace='NA',value='GULSHAN')

# %%
df['First Name'].sample(10)
# Out:
# 826     GULSHAN
# 2         Maria
# 915        Todd
# 273    Nicholas
# 627        Anne
# 258     Michael
# 723     Brandon
# 794      Nicole
# 905       Alice
# 653       Debra
# Name: First Name, dtype: object

# %%
df['Gender'].sample(20)
# Out:
# 591    Female
# 398    Female
# 622    Female
# 885      Male
# 124    Female
# 627    Female
# 772    Female
# 70        NaN
# 695    Female
# 190    Female
# 484      Male
# 994      Male
# 460    Female
# 468    Female
# 511      Male
# 859    Female
# 83       Male
# 647      Male
# 308    Female
# 541    Female
# Name: Gender, dtype: object

# %% [markdown]
# df['Gender']= df['Gender'].replace(to_replace='NaN',value='')

# %% [markdown]
# df['Gender'].sample(20)

# %%
# plt.scatter(df['Salary'],df['Bonus %'],hue='Gender')
sns.scatterplot(df)
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df, x="Salary", y="Bonus %", hue="Gender", style="Gender")
# Out:
# <Axes: xlabel='Salary', ylabel='Bonus %'>

# %%
profile=ProfileReport(df)

# %%
profile.to_file('report.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#x = df.drop(['First Name','Gender','Start Date'])
#2d
x= df[['Salary']]

# %%
y=df['Bonus %']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y)

# %%
x_train.shape
# Out:
# (750, 1)

# %%
y_test.shape
# Out:
# (250,)

# %%
from sklearn.linear_model import LinearRegression

# %%
#building models
gk =LinearRegression()

# %%
#training models 
gk.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
gk.predict(x_test)
# Out:
# array([10.15845832,  9.78521578, 10.35493987, 10.29804296, 10.61133805,
#        10.31407362,  9.80682367,  9.92343692, 10.17512066, 10.05773707,
#        10.2046861 , 10.3119629 , 10.6457412 , 10.00318967,  9.78884406,
#         9.81953419, 10.35762064, 10.55520377, 10.13781335, 10.49773681,
#        10.22595504, 10.07855921, 10.11758436, 10.64309125, 10.57500907,
#        10.00389838,  9.9157952 ,  9.80272549, 10.36154934, 10.4576794 ,
#        10.40270832, 10.19306945, 10.1549687 , 10.55622831, 10.42362291,
#        10.46198557, 10.63351599, 10.45042285, 10.60076906,  9.98675073,
#        10.50980795, 10.38230986,  9.82661356, 10.66010024, 10.35047193,
#         9.85966862, 10.07953754, 10.21243567, 10.57242075,  9.78439152,
#        10.52848086, 10.60722447, 10.00437598, 10.2585556 , 10.22166428,
#        10.44071664, 10.2387426 ,  9.89957966, 10.18552788, 10.48572729,
#        10.41924741,  9.97191408, 10.24583738, 10.495187  ,  9.789183  ,
# ...

# %%
y_pred = gk.predict(x_test)

# %%
gk.predict([[97308]])
# Out:
# C:\Users\ses13\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([10.18692989])

# %%
#co efficient
gk.intercept_
# Out:
# 10.936527119846568

# %%
gk.coef_
# Out:
# array([-7.70334641e-06])

# %%
# y=mx+c
-7.70334641e-06*97308+10.936527119846568
# Out:
# 10.186929887382288

# %%
form sklearn.metrics import r2_score,mean_square
