# %%
#Define objectives, understanding data, resources

import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <img src='1.jpg' height = 3>

# %%
df = pd.read_csv('practice.csv')
df.head(1)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
#
#    body_mass_g   sex
# 0       3750.0  Male

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.dropna()
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
df['bill_length_mm']
# Out:
# 0      39.1
# 1      39.5
# 2      40.3
# 3       NaN
# 4      36.7
#        ...
# 339     NaN
# 340    46.8
# 341    50.4
# 342    45.2
# 343    49.9
# Name: bill_length_mm, Length: 344, dtype: float64

# %%
sns.distplot(df['bill_length_mm'],kde=True)
# Out:
# C:\Users\SES-5\AppData\Local\Temp\ipykernel_10816\1152263247.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bill_length_mm'],kde=True)
# <Axes: xlabel='bill_length_mm', ylabel='Density'>

# %%
sns.displot(df['bill_length_mm'], rug=True, color='m')

# %%
plt.figure(figsize=(4,4))
sns.histplot(df['bill_length_mm']) #, bins=[30,60,40,44,48]
plt.show()

# %%
x = np.random.randint(30,99,155)
x
# Out:
# array([87, 46, 51, 53, 73, 53, 78, 67, 88, 35, 86, 90, 89, 94, 48, 80, 51,
#        41, 72, 46, 70, 55, 95, 94, 53, 62, 65, 74, 95, 97, 51, 94, 66, 30,
#        48, 80, 39, 82, 62, 71, 37, 91, 45, 52, 36, 49, 65, 51, 64, 89, 93,
#        68, 51, 63, 44, 63, 65, 90, 32, 76, 32, 36, 78, 52, 97, 59, 77, 38,
#        68, 72, 88, 94, 90, 67, 58, 54, 37, 51, 34, 64, 75, 70, 55, 34, 90,
#        56, 77, 58, 62, 82, 95, 34, 32, 48, 46, 96, 85, 83, 62, 58, 86, 89,
#        43, 69, 85, 86, 63, 73, 30, 90, 67, 61, 79, 93, 35, 94, 31, 56, 56,
#        69, 61, 74, 91, 57, 34, 79, 55, 81, 56, 85, 30, 71, 42, 57, 62, 65,
#        91, 31, 38, 35, 54, 39, 90, 76, 92, 94, 66, 33, 66, 38, 87, 62, 65,
#        45, 36])

# %%
x = [58, 44, 84, 63, 46, 62, 33, 35, 83, 89, 95, 93, 41, 88, 67, 50, 33,
       44, 51, 94, 52, 86, 79, 68, 54, 36, 93, 86, 95, 96, 95, 36, 46, 49,
       41, 60, 36, 86, 78, 72, 43, 90, 66, 63, 59, 81, 55, 87, 34, 95, 49,
       90, 74, 48, 33, 34, 93, 37, 86, 31, 85, 67, 48, 45, 82, 68, 42, 38,
       73, 68, 84, 94, 45, 66, 62, 71, 61, 44, 49, 70, 86, 55, 74, 75, 58,
       52, 88, 98, 44, 56, 41, 79, 92, 66, 78, 96, 98, 62, 92, 64, 94, 83,
       31, 41, 87, 51, 85, 87, 88, 59, 93, 83, 80, 88, 64, 52, 82, 62, 83,
       62, 53, 63, 85, 42, 71, 48, 54, 44, 94, 68, 84, 82, 37, 30, 70, 85,
       71, 61, 43, 37, 33, 98, 37, 83, 52, 61, 48, 58, 97, 69, 73, 53, 90,
       31, 46]
sns.distplot(x,bins=[40,50,60,70,80,90,100])
# Out:
# C:\Users\SES-5\AppData\Local\Temp\ipykernel_10816\4228247529.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x,bins=[40,50,60,70,80,90,100])
# <Axes: ylabel='Density'>

# %%
x =np.random.randint(10,1000,150)
sns.displot(x, log_scale=True)
plt.show()

# %%
#line Plot

# %%
roll = [1,2,3,4,5]
marks = [69,82,73,79]
df = [roll, marks]
sns.lineplot(data=df )
# Out:
# <Axes: >

# %%
roll = [1,2,3,4,5,6,7,8]
mark = [69,82,73,79]
df = pd.DataFrame({'Roll No':roll, 'Marks':mark})
sns.lineplot(x ='Roll No',y='Marks', data=df )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 3
#       1 roll = [1,2,3,4,5,6,7,8]
#       2 mark = [69,82,73,79]
# ----> 3 df = pd.DataFrame({'Roll No':roll, 'Marks':mark})
#       4 sns.lineplot(x ='Roll No',y='Marks', data=df )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# ...

# %%
df = pd.read_csv('practice.csv')
df.head(50)

# %%
sns.lineplot(x='body_mass_g',y='bill_length_mm',data=df,style='island')

# %%
sns.lineplot(x='body_mass_g',y='bill_length_mm',data=df,hue='sex',style='island',
markers=['^','o','>'],palette='Pastel2',legend='brief')

# %%
df

# %%
#barplot    'Adelie','Gentoo island','Biscoe island'  ,palette='copper',fill=False
sns.set_style('darkgrid')
sns.barplot(x = 'island',y='body_mass_g',data=df,hue='sex',order=['Torgersen','Dream','Biscoe'],ci=10,saturation=0.50,)

# %%
sns.pairplot(df)

# %%
df
# Out:
# [[1, 2, 3, 4, 5], [69, 82, 73, 79]]

# %% [markdown]
# # 16-10-2023

# %%
df = pd.read_csv('practice.csv')
df.head(1)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
#
#    body_mass_g   sex
# 0       3750.0  Male

# %%
plt.figure(figsize=(4,4))#'prism','hot','Accent'
sns.countplot(x='species',data=df,hue='sex',palette='cool'        )
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
df3 = df.drop(['species','bill_length_mm'],axis=1)
sns.boxplot(df3)
# Out:
# <Axes: >

# %%
time=[1,2,3,4,5,6,7]
marks=[40,41,45,51,57,79,80]
enjoyment = [90,78,57,89,40,89,70]
df2 = pd.DataFrame(time,marks)
df2
# Out:
#     0
# 40  1
# 41  2
# 45  3
# 51  4
# 57  5
# 79  6
# 80  7

# %%
df2.corr()
# Out:
#      0
# 0  1.0

# %%
sns.heatmap(df2.corr())
# Out:
# <Axes: >

# %%
plt.figure(figsize=(4,4))
plot1 = sns.heatmap(df2.corr(),annot=True,cmap='cool',linewidth=5,cbar=False)
#plot1.seyt(xlabel='collage',ylabel='output')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('practice.csv')
df.head(1)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
#
#    body_mass_g   sex
# 0       3750.0  Male

# %%
plt.figure(figsize=(4,4)) 
sns.violinplot(x='island',y='body_mass_g',data=df, palette='cool')
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %%
plt.figure(figsize=(4,4)) 
sns.violinplot(x='island',y='body_mass_g',data=df, palette='cool',saturation=0.8, order=['Dream','Torgersen'])
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %%
sns.violinplot(x='island',y='body_mass_g', data=df,hue='sex',split=True,scale='width')
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %%
#inner='quart','point'
sns.violinplot(x='island',y='body_mass_g', data=df,hue='sex',split=True,fill=False,gap=1,inner='stick')
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %%
    plt.figure(figsize=(4,4))
    sns.stripplot(x='body_mass_g',data=df)
# Out:
# <Axes: xlabel='body_mass_g'>

# %%
plt.figure(figsize=(4,4))
sns.stripplot(x='bill_depth_mm',y='body_mass_g', data=df, palette='cool')
# Out:
# C:\Users\SES-5\AppData\Local\Temp\ipykernel_11496\1387534035.py:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(x='bill_depth_mm',y='body_mass_g', data=df, palette='cool')
# <Axes: xlabel='bill_depth_mm', ylabel='body_mass_g'>

# %%
sns.scatterplot(df)
# Out:
# <Axes: >

# %%
sns.boxplot(x='bill_depth_mm',y='body_mass_g',data=df, hue='sex', color='g', showmeans=True, meanprops={"marker":"D","markeredgecolor":"r"}, palette='')
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='body_mass_g'>

# %% [markdown]
# # 17-10-2023

# %%
#catplot, pairplot , facent Grid
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head(1)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2

# %%
figr = sns.FacetGrid(df, col='day', hue='sex',palette='cool')
figr.map(plt.scatter, 'total_bill','tip')
figr.add_legend()
plt.show()

# %%
df.head(1)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2

# %%
plt.figure(figsize=(6,6))
sns.pairplot(df)

# %%
plt.figure(figsize=(6,6))
sns.pairplot(df,hue='sex')
plt.show()

# %%
#cat plot
sns.catplot(x='total_bill', y='tip' , data=df)

# %%
sns.catplot(x='size', y='tip' , data=df.head(50), hue='tip', palette='Accent',kind='point')

# %%
sns.catplot(x='size', y='tip' , data=df.head(50), hue='sex', palette='Accent',kind='point')

# %%
sns.catplot(x='size', y='tip' , data=df)

# %%
plt.figure(figsize=(3,3))
sns.catplot(x='size',data=df.head(30),hue='sex')

# %%
import streamlit as st
st.title('my frist ds app')
st.header('dataset')
st.subheader('first dataset')
st.caption('Iris')
st.write('Iris')
st.code('for x in a')
st.markdown('data')
st.checkbox('agree to the terms')
st.button('Submit')
# Out:
# False

# %% [markdown]
# # Afternoon Session

# %%
import mpl_toolkits as mpt
import numpy as np
import matplotlib.pyplot as plt

# %%
#plot3D
x = np.array([1,2,3,4,5])
y = np.array([3,5,1,9,6])
z = np.ones(5)

# %%
fig = plt.figure()
ax = plt.axes(projection ='3d')
ax.plot3D(x,y,z, marker='D',color='y',mec='k')
plt.show()

# %%
#Barplot
x = np.array([1,2,3,4,5,6,7])
y = np.array([3,5,1,9,6,4,5])
z = np.ones(7)

# %%
xsize=np.ones(7)
ysize=np.ones(7)
zsize=np.array([2,3,2,5,3,4,2])

# %%
fig = plt.figure()
ax = plt.axes(projection ='3d')
ax.bar3d(x,y,z,xsize,ysize,zsize)
plt.show()

# %%
#Scatter plot
x = np.array([1,2,3,4,5,6,7])
y = np.array([3,5,1,9,6,4,5])
z = np.ones(7)

# %%
fig = plt.figure()
ax = plt.axes(projection ='3d')
ax.scatter3D(x,y,z, c='m')
plt.show()
