# %%
import pandas as pd # pd -alias for pandas

# %%
# Series
y =[4,8,9,5,6,8]
a= pd.Series(y, index= ['a','b','c','d','e','f'], dtype = 'float')
a
# Out:
# a    4.0
# b    8.0
# c    9.0
# d    5.0
# e    6.0
# f    8.0
# dtype: float64

# %%
print(type(a))
# Out:
# <class 'pandas.core.series.Series'>

# %%
y1 = {'name':['Seema','dk','pk','ok']}
a1 = pd.Series(y1)
a1
# Out:
# name    [Seema, dk, pk, ok]
# dtype: object

# %%
a1 =[2]

# %%
y2 = ['Seema','Manisha','Pooja',102]
a2 = pd.Series(y2)
a2
# Out:
# 0      Seema
# 1    Manisha
# 2      Pooja
# 3        102
# dtype: object

# %%
y3 ={'name':['Seema','Pooja'],' age':[20,22]}
a3 = pd.Series(y3)
a3
# Out:
# name    [Seema, Pooja]
#  age          [20, 22]
# dtype: object

# %%
print(type(a3))
# Out:
# <class 'pandas.core.series.Series'>

# %%
y4 = pd.Series(10, index=[101,102,103,104,105])
y5 =pd.Series(20, index=[101,102,103])
print(y5)
print(y4)
# Out:
# 101    20
# 102    20
# 103    20
# dtype: int64
# 101    10
# 102    10
# 103    10
# 104    10
# 105    10
# dtype: int64

# %%
print(y4+y5)
# Out:
# 101    30.0
# 102    30.0
# 103    30.0
# 104     NaN
# 105     NaN
# dtype: float64

# %%
print(y4-y5)
# Out:
# 101   -10.0
# 102   -10.0
# 103   -10.0
# 104     NaN
# 105     NaN
# dtype: float64

# %%
b = (y4+y5)
c =pd.Series(b ,dtype='int_')
c
# Out:
# 101    30.0
# 102    30.0
# 103    30.0
# 104     NaN
# 105     NaN
# dtype: float64

# %%
# Data Frames

# %%
y =[4,8,5,8,7,8,9,5]
a =pd.DataFrame(y)
a
# Out:
#    0
# 0  4
# 1  8
# 2  5
# 3  8
# 4  7
# 5  8
# 6  9
# 7  5

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
y3 ={'name':['Seema','dk'], 'age':[21,22], 'mail':'ok@gmail.com'}
a3 =pd.DataFrame(y3, index=['a','b'])
a3
# Out:
#     name  age          mail
# a  Seema   21  ok@gmail.com
# b     dk   22  ok@gmail.com

# %%
a4=pd.DataFrame(y3, columns=['name'])
a4
# Out:
#     name
# 0  Seema
# 1     dk

# %%
b1 =pd.DataFrame(a)
b1
# Out:
#    0
# 0  4
# 1  8
# 2  5
# 3  8
# 4  7
# 5  8
# 6  9
# 7  5

# %%
b2 = {'Student':['Seema','DK','OK'],'Markes':[23,20,21]}
df = pd.DataFrame(b2)
df
# Out:
#   Student  Markes
# 0   Seema      23
# 1      DK      20
# 2      OK      21

# %%
df.shape
# Out:
# (3, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Student  3 non-null      object
#  1   Markes   3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
a = {'Name':['Seema','Reema','DK'],
     'Salary':[21000,2523,5426],
    'City':['Jind','Haryana','Hr'],
    'IsEmployee':[True,False,True]}
b = pd.DataFrame(a)
b
# Out:
#     Name  Salary     City  IsEmployee
# 0  Seema   21000     Jind        True
# 1  Reema    2523  Haryana       False
# 2     DK    5426       Hr        True

# %%
b.shape

# %%
b.describe()
# Out:
#              Salary
# count      3.000000
# mean    9649.666667
# std     9936.267022
# min     2523.000000
# 25%     3974.500000
# 50%     5426.000000
# 75%    13213.000000
# max    21000.000000

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        3 non-null      object
#  1   Salary      3 non-null      int64
#  2   City        3 non-null      object
#  3   IsEmployee  3 non-null      bool
# dtypes: bool(1), int64(1), object(2)
# memory usage: 207.0+ bytes

# %%
# print('no of rows are:',rows)

# %%
# columns

# %%
b
# Out:
#     Name  Salary     City  IsEmployee
# 0  Seema   21000     Jind        True
# 1  Reema    2523  Haryana       False
# 2     DK    5426       Hr        True

# %%
b.to_csv('csv.csv')

# %%
import pandas as pd

# %%
a = {'Name':['Seema','OK','DK'],
     'Salary':[21000,2523,5426],
    'City':['Jind','Haryana','Hr'],
    'IsEmployee':[True,False,True]}
b = pd.DataFrame(a)
b
# Out:
#     Name  Salary     City  IsEmployee
# 0  Seema   21000     Jind        True
# 1     OK    2523  Haryana       False
# 2     DK    5426       Hr        True

# %%
import pandas as pd
a = pd.read_csv('csv.csv')
a
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  3 non-null      int64
#  1   Name        3 non-null      object
#  2   Salary      3 non-null      int64
#  3   City        3 non-null      object
#  4   IsEmployee  3 non-null      bool
# dtypes: bool(1), int64(2), object(2)
# memory usage: 231.0+ bytes

# %%
a.shape
# Out:
# (3, 5)

# %%
a.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
a_1=a.dropna()
a_1
# Out:
#    Unnamed: 0   Name  Salary     City  IsEmployee
# 0           0  Seema   21000     Jind        True
# 1           1  Reema    2523  Haryana       False
# 2           2     DK    5426       Hr        True

# %%
a_2 =a
a_2
# Out:
#    Unnamed: 0   Name  Salary     City  IsEmployee
# 0           0  Seema   21000     Jind        True
# 1           1  Reema    2523  Haryana       False
# 2           2     DK    5426       Hr        True

# %%
a ['City'].fillna(31)
a
# Out:
#    Unnamed: 0   Name  Salary     City  IsEmployee
# 0           0  Seema   21000     Jind        True
# 1           1  Reema    2523  Haryana       False
# 2           2     DK    5426       Hr        True

# %%
x =a['Salary'].mean()
x
# Out:
# 9649.666666666666

# %%
a ['Salary'].fillna(x)
# Out:
# 0    21000
# 1     2523
# 2     5426
# Name: Salary, dtype: int64

# %%
a['Salary'].mode()
# Out:
# 0     2523
# 1     5426
# 2    21000
# Name: Salary, dtype: int64

# %%
a['Salary'].median()
# Out:
# 5426.0

# %%
print(type(a))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
a_4 =a.index
a_4
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
a.index.drop
# Out:
# <bound method Index.drop of RangeIndex(start=0, stop=3, step=1)>

# %%
import pandas as pd

# %%
df = pd.read_csv('marks1.csv')
df
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science
# 0          Smriti Ranjan       85     83     93       91              94
# 1          Tannu kumari        90     75     78       73              75
# 2                  Seema       93     98     78       89              94
# 3          Mukesh Nirmal       92     71     72       96              75
# 4                  rohit       75     78     87       90              87
# 5               Ramakant       84     76     75       76              96
# 6    Vinod Kumar Sharma        75     96     74       81              71
# 7     Gulshan Kumar Ray        73     74     84       76              85
# 8    Ashutosh Kumar raj        89     70     80       97              95
# 9             Amit kumar       80     71     73       87              96
# 10          Astha sachan       77     71     77       95              72
# 11          Shail Kumari       95     97     80       92              92
# ...

# %%
df.head(1)
# Out:
#             Name  English  Hindi  Maths  Science  Social Science
# 0  Smriti Ranjan       85     83     93       91              94

# %%
df.tail(5)
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science
# 16                 Pooja       75     85     89       56              65
# 17                Seema.       93     75     78       89              94
# 18          Shail Kumari       95     97     80       92              92
# 19  Vaishnavi Kesherwani       82     80     88       91              71
# 20             Rahul Rai       75     77     76       80              78

# %%
df['Total']=0
# df.info()

# %%
df['Total']= df['English']+df['Hindi']+ df['Maths']+df['Science']+df['Social Science']
df
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science  \
# 0          Smriti Ranjan       85     83     93       91              94
# 1          Tannu kumari        90     75     78       73              75
# 2                  Seema       93     98     78       89              94
# 3          Mukesh Nirmal       92     71     72       96              75
# 4                  rohit       75     78     87       90              87
# 5               Ramakant       84     76     75       76              96
# 6    Vinod Kumar Sharma        75     96     74       81              71
# 7     Gulshan Kumar Ray        73     74     84       76              85
# 8    Ashutosh Kumar raj        89     70     80       97              95
# 9             Amit kumar       80     71     73       87              96
# 10          Astha sachan       77     71     77       95              72
# 11          Shail Kumari       95     97     80       92              92
# ...

# %%
df ['Percentage'] =df['Total']/500*100
df
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science  \
# 0          Smriti Ranjan       85     83     93       91              94
# 1          Tannu kumari        90     75     78       73              75
# 2                  Seema       93     98     78       89              94
# 3          Mukesh Nirmal       92     71     72       96              75
# 4                  rohit       75     78     87       90              87
# 5               Ramakant       84     76     75       76              96
# 6    Vinod Kumar Sharma        75     96     74       81              71
# 7     Gulshan Kumar Ray        73     74     84       76              85
# 8    Ashutosh Kumar raj        89     70     80       97              95
# 9             Amit kumar       80     71     73       87              96
# 10          Astha sachan       77     71     77       95              72
# 11          Shail Kumari       95     97     80       92              92
# ...

# %%
df.loc[(df['English'] >=90)|(df['Maths'] >= 90) & (df['Hindi'] >= 90)]
# Out:
#              Name  English  Hindi  Maths  Science  Social Science  Total  \
# 1   Tannu kumari        90     75     78       73              75    391
# 2           Seema       93     98     78       89              94    452
# 3   Mukesh Nirmal       92     71     72       96              75    406
# 11   Shail Kumari       95     97     80       92              92    456
# 14         Trapti       91     95     74       94              98    452
# 17         Seema.       93     75     78       89              94    429
# 18   Shail Kumari       95     97     80       92              92    456
#
#     Percentage
# 1         78.2
# 2         90.4
# 3         81.2
# 11        91.2
# 14        90.4
# 17        85.8
# 18        91.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            21 non-null     object
#  1   English         21 non-null     int64
#  2   Hindi           21 non-null     int64
#  3   Maths           21 non-null     int64
#  4   Science         21 non-null     int64
#  5   Social Science  21 non-null     int64
#  6   Total           21 non-null     int64
#  7   Percentage      21 non-null     float64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 1.4+ KB

# %%
df['Grade']= 'Pass'
df
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science  \
# 0          Smriti Ranjan       85     83     93       91              94
# 1          Tannu kumari        90     75     78       73              75
# 2                  Seema       93     98     78       89              94
# 3          Mukesh Nirmal       92     71     72       96              75
# 4                  rohit       75     78     87       90              87
# 5               Ramakant       84     76     75       76              96
# 6    Vinod Kumar Sharma        75     96     74       81              71
# 7     Gulshan Kumar Ray        73     74     84       76              85
# 8    Ashutosh Kumar raj        89     70     80       97              95
# 9             Amit kumar       80     71     73       87              96
# 10          Astha sachan       77     71     77       95              72
# 11          Shail Kumari       95     97     80       92              92
# ...

# %%
df.loc[df['Percentage'] >= 85, ['Grade']] ='Distniction'
df
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science  \
# 0          Smriti Ranjan       85     83     93       91              94
# 1          Tannu kumari        90     75     78       73              75
# 2                  Seema       93     98     78       89              94
# 3          Mukesh Nirmal       92     71     72       96              75
# 4                  rohit       75     78     87       90              87
# 5               Ramakant       84     76     75       76              96
# 6    Vinod Kumar Sharma        75     96     74       81              71
# 7     Gulshan Kumar Ray        73     74     84       76              85
# 8    Ashutosh Kumar raj        89     70     80       97              95
# 9             Amit kumar       80     71     73       87              96
# 10          Astha sachan       77     71     77       95              72
# 11          Shail Kumari       95     97     80       92              92
# ...

# %%
df.loc[df['Percentage'] >= 85, ['Grade']] ='Distniction'
df.loc[(df['Percentage']>= 80) & (df['Percentage']<85), ['Grade']]="first"
df.loc[(df['Percentage']>= 75) & (df['Percentage']<80), ['Grade']]="Second"
df.loc[(df['Percentage']>= 75) & (df['Percentage']<80), ['Grade']]="Pass"
df.loc[(df['Percentage']< 75),['Grade']]="Fail"
df.loc[~(df['Percentage'] >= 0), ['Grade']] ='NAN'
df
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science  \
# 0          Smriti Ranjan       85     83     93       91              94
# 1          Tannu kumari        90     75     78       73              75
# 2                  Seema       93     98     78       89              94
# 3          Mukesh Nirmal       92     71     72       96              75
# 4                  rohit       75     78     87       90              87
# 5               Ramakant       84     76     75       76              96
# 6    Vinod Kumar Sharma        75     96     74       81              71
# 7     Gulshan Kumar Ray        73     74     84       76              85
# 8    Ashutosh Kumar raj        89     70     80       97              95
# 9             Amit kumar       80     71     73       87              96
# 10          Astha sachan       77     71     77       95              72
# 11          Shail Kumari       95     97     80       92              92
# ...

# %%
df.loc[df['Name'].str.contains('S')]
# Out:
#                    Name  English  Hindi  Maths  Science  Social Science  \
# 0         Smriti Ranjan       85     83     93       91              94
# 2                 Seema       93     98     78       89              94
# 6   Vinod Kumar Sharma        75     96     74       81              71
# 11         Shail Kumari       95     97     80       92              92
# 17               Seema.       93     75     78       89              94
# 18         Shail Kumari       95     97     80       92              92
#
#     Total  Percentage        Grade
# 0     446        89.2  Distniction
# 2     452        90.4  Distniction
# 6     397        79.4         Pass
# 11    456        91.2  Distniction
# 17    429        85.8  Distniction
# 18    456        91.2  Distniction

# %%
df.loc[df['Name'].str.endswith('a')]
# Out:
#      Name  English  Hindi  Maths  Science  Social Science  Total  Percentage  \
# 2   Seema       93     98     78       89              94    452        90.4
# 16  Pooja       75     85     89       56              65    370        74.0
#
#           Grade
# 2   Distniction
# 16         Fail

# %%
df
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science  \
# 0          Smriti Ranjan       85     83     93       91              94
# 1          Tannu kumari        90     75     78       73              75
# 2                  Seema       93     98     78       89              94
# 3          Mukesh Nirmal       92     71     72       96              75
# 4                  rohit       75     78     87       90              87
# 5               Ramakant       84     76     75       76              96
# 6    Vinod Kumar Sharma        75     96     74       81              71
# 7     Gulshan Kumar Ray        73     74     84       76              85
# 8    Ashutosh Kumar raj        89     70     80       97              95
# 9             Amit kumar       80     71     73       87              96
# 10          Astha sachan       77     71     77       95              72
# 11          Shail Kumari       95     97     80       92              92
# ...

# %%
df.style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_8af4a">
#   <thead>
#     <tr>
#       <th id="T_8af4a_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_8af4a_level0_col1" class="col_heading level0 col1" >English</th>
#       <th id="T_8af4a_level0_col2" class="col_heading level0 col2" >Hindi</th>
#       <th id="T_8af4a_level0_col3" class="col_heading level0 col3" >Maths</th>
#       <th id="T_8af4a_level0_col4" class="col_heading level0 col4" >Science</th>
#       <th id="T_8af4a_level0_col5" class="col_heading level0 col5" >Social Science</th>
#       <th id="T_8af4a_level0_col6" class="col_heading level0 col6" >Total</th>
#       <th id="T_8af4a_level0_col7" class="col_heading level0 col7" >Percentage</th>
#       <th id="T_8af4a_level0_col8" class="col_heading level0 col8" >Grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8af4a_row0_col0" class="data row0 col0" >Smriti Ranjan</td>
# ...

# %%
df.style.highlight_min()
# Out:
# <style type="text/css">
# #T_df8a5_row0_col8, #T_df8a5_row2_col8, #T_df8a5_row3_col3, #T_df8a5_row8_col2, #T_df8a5_row8_col8, #T_df8a5_row9_col0, #T_df8a5_row11_col8, #T_df8a5_row14_col8, #T_df8a5_row15_col1, #T_df8a5_row16_col4, #T_df8a5_row16_col5, #T_df8a5_row16_col6, #T_df8a5_row16_col7, #T_df8a5_row17_col8, #T_df8a5_row18_col8 {
#   background-color: yellow;
# }
# </style>
# <table id="T_df8a5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_df8a5_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_df8a5_level0_col1" class="col_heading level0 col1" >English</th>
#       <th id="T_df8a5_level0_col2" class="col_heading level0 col2" >Hindi</th>
#       <th id="T_df8a5_level0_col3" class="col_heading level0 col3" >Maths</th>
#       <th id="T_df8a5_level0_col4" class="col_heading level0 col4" >Science</th>
#       <th id="T_df8a5_level0_col5" class="col_heading level0 col5" >Social Science</th>
# ...

# %%
df.style.highlight_max()
# Out:
# <style type="text/css">
# #T_db3ba_row0_col3, #T_db3ba_row2_col2, #T_db3ba_row3_col8, #T_db3ba_row4_col0, #T_db3ba_row4_col8, #T_db3ba_row5_col8, #T_db3ba_row8_col4, #T_db3ba_row9_col8, #T_db3ba_row11_col1, #T_db3ba_row11_col6, #T_db3ba_row11_col7, #T_db3ba_row12_col8, #T_db3ba_row14_col5, #T_db3ba_row15_col8, #T_db3ba_row18_col1, #T_db3ba_row18_col6, #T_db3ba_row18_col7, #T_db3ba_row19_col8 {
#   background-color: yellow;
# }
# </style>
# <table id="T_db3ba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db3ba_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_db3ba_level0_col1" class="col_heading level0 col1" >English</th>
#       <th id="T_db3ba_level0_col2" class="col_heading level0 col2" >Hindi</th>
#       <th id="T_db3ba_level0_col3" class="col_heading level0 col3" >Maths</th>
#       <th id="T_db3ba_level0_col4" class="col_heading level0 col4" >Science</th>
# ...

# %%
df.style.highlight_null()
# Out:
# <style type="text/css">
# </style>
# <table id="T_bdeed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bdeed_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_bdeed_level0_col1" class="col_heading level0 col1" >English</th>
#       <th id="T_bdeed_level0_col2" class="col_heading level0 col2" >Hindi</th>
#       <th id="T_bdeed_level0_col3" class="col_heading level0 col3" >Maths</th>
#       <th id="T_bdeed_level0_col4" class="col_heading level0 col4" >Science</th>
#       <th id="T_bdeed_level0_col5" class="col_heading level0 col5" >Social Science</th>
#       <th id="T_bdeed_level0_col6" class="col_heading level0 col6" >Total</th>
#       <th id="T_bdeed_level0_col7" class="col_heading level0 col7" >Percentage</th>
#       <th id="T_bdeed_level0_col8" class="col_heading level0 col8" >Grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bdeed_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
import pandas as pd

# %%
df.style.bar()
# Out:
# <style type="text/css">
# #T_d3cd7_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 89.5%, transparent 89.5%);
# }
# #T_d3cd7_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 84.7%, transparent 84.7%);
# }
# #T_d3cd7_row0_col3, #T_d3cd7_row2_col2, #T_d3cd7_row8_col4, #T_d3cd7_row11_col1, #T_d3cd7_row11_col6, #T_d3cd7_row11_col7, #T_d3cd7_row14_col5, #T_d3cd7_row18_col1, #T_d3cd7_row18_col6, #T_d3cd7_row18_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_d3cd7_row0_col4, #T_d3cd7_row12_col4, #T_d3cd7_row19_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 93.8%, transparent 93.8%);
# }
# #T_d3cd7_row0_col5, #T_d3cd7_row2_col5, #T_d3cd7_row17_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 95.9%, transparent 95.9%);
# }
# #T_d3cd7_row0_col6, #T_d3cd7_row0_col7 {
#   width: 10em;
# ...

# %%
df = pd.read_csv('marks1.csv')
df
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science
# 0          Smriti Ranjan       85     83     93       91              94
# 1          Tannu kumari        90     75     78       73              75
# 2                  Seema       93     98     78       89              94
# 3          Mukesh Nirmal       92     71     72       96              75
# 4                  rohit       75     78     87       90              87
# 5               Ramakant       84     76     75       76              96
# 6    Vinod Kumar Sharma        75     96     74       81              71
# 7     Gulshan Kumar Ray        73     74     84       76              85
# 8    Ashutosh Kumar raj        89     70     80       97              95
# 9             Amit kumar       80     71     73       87              96
# 10          Astha sachan       77     71     77       95              72
# 11          Shail Kumari       95     97     80       92              92
# ...

# %%
df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_86715_row0_col1 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_86715_row0_col2 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_86715_row0_col3, #T_86715_row2_col2, #T_86715_row8_col4, #T_86715_row11_col1, #T_86715_row14_col5, #T_86715_row18_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_86715_row0_col4, #T_86715_row12_col4, #T_86715_row19_col4 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_86715_row0_col5, #T_86715_row2_col5, #T_86715_row11_col4, #T_86715_row17_col5, #T_86715_row18_col4 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_86715_row1_col1 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_86715_row1_col2, #T_86715_row15_col2, #T_86715_row17_col2 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_86715_row1_col3, #T_86715_row2_col3, #T_86715_row4_col2, #T_86715_row17_col3 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# ...

# %%
df.style.set_properties(**{'color':'green','background':'cyan','border':'3px dashed orange'})
# Out:
# <style type="text/css">
# ...

# %%
#
import pandas as pd
import mysql.connector

# %%
# a = mysql.connector.connect(
# host = 'localhost',
# user = 'root',
# password = '',
# database = 'nsti'
# )

# %%
df = pd.read_sql('SELECT * FROM `getvatsacursor`',a)
a.close()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_11764\4206532880.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql('SELECT * FROM `getvatsacursor`',a)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11764\4206532880.py in ?()
# ----> 1 df = pd.read_sql('SELECT * FROM `getvatsacursor`',a)
#       2 a.close()
#       3
#       4
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py in ?(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     631         dtype_backend = "numpy"  # type: ignore[assignment]
#     632
#     633     with pandasSQL_builder(con) as pandas_sql:
# ...

# %%
df

# %%
# df1 = pd.read_json("sample.json")
# df1

# %%
import pandas as pd

df3 =pd.read_html('https://nstidehradun.dgt.gov.in/')
df3
# Out:
# [                                                   0
#  0  कौशल उड़ान हिंदी पत्रिका (अप्रैल से सितंबर 202...
#  1  दीक्षांत समारोह 2022-23 हेतु आमंत्रण Invitatio...
#  2  राष्ट्रीय खेल दिवस 2023/ National Sports Day 2023
#  3  एनएसटीआई देहरादून में स्वतंत्रता दिवस Independ...
#  4  सीटीएस सत्र 2023-24 प्रवेश सूचना CTS Session 2...,
#                                                     0
#  0  कौशल उड़ान हिंदी पत्रिका (अप्रैल से सितंबर 202...
#  1  अतिथि व्याख्याता की नियुक्ति के लिए विज्ञापन/A...
#  2  सीटीएस 2022-23 प्रवेश अधिसूचना CTS 2022-23 Adm...
#  3       Important-revised Instructions for AITT CITS
#  4                     Recruitment Notice No. 02/2021]

# %%
import html5lib
df4 =pd.read_html('')
df4

# %%
a =pd.DataFrame()
a
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
 import pandas as pd
df2 =pd.read_csv('marks1.csv')
df2
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science
# 0          Smriti Ranjan       85     83     93       91              94
# 1          Tannu kumari        90     75     78       73              75
# 2                  Seema       93     98     78       89              94
# 3          Mukesh Nirmal       92     71     72       96              75
# 4                  rohit       75     78     87       90              87
# 5               Ramakant       84     76     75       76              96
# 6    Vinod Kumar Sharma        75     96     74       81              71
# 7     Gulshan Kumar Ray        73     74     84       76              85
# 8    Ashutosh Kumar raj        89     70     80       97              95
# 9             Amit kumar       80     71     73       87              96
# 10          Astha sachan       77     71     77       95              72
# 11          Shail Kumari       95     97     80       92              92
# ...

# %%
df3 =pd.read_csv('m2.csv')
df3
# Out:
#                   Name                           Mail  Location  Maths  \
# 0        Smriti Ranjan       smritiranjan65@gmail.com     Patna     93
# 1        Tannu kumari         tkumari930451@gmail.com     Patna     78
# 2                Seema      dksainiaggarwal@gmail.com  Dehradun     78
# 3        Mukesh Nirmal      nirmalmukesh200@gmail.com  Dehradun     72
# 4                rohit                            NaN       NaN     87
# 5             Ramakant  ramakantprajapati11@gmail.com  Dehradun     75
# 6  Vinod Kumar Sharma     vinodsharma740860@gmail.com    Kanpur     74
# 7   Gulshan Kumar Ray         raygulshan960@gmail.com  Dehradun     83
# 8  Ashutosh Kumar raj        ashutoshraj822@gmail.com     Patna     89
#
#    Science  Social Science
# 0     91.0            94.0
# 1     73.0            75.0
# 2     89.0            94.0
# 3     96.0            75.0
# 4     90.0            87.0
# 5     76.0            96.0
# 6      NaN             NaN
# 7      NaN             NaN
# ...

# %%
pd.merge(df2,df3)
# Out:
#             Name  English  Hindi  Maths  Science  Social Science  \
# 0  Smriti Ranjan       85     83     93       91              94
# 1  Tannu kumari        90     75     78       73              75
# 2          Seema       93     98     78       89              94
# 3  Mukesh Nirmal       92     71     72       96              75
# 4          rohit       75     78     87       90              87
# 5       Ramakant       84     76     75       76              96
#
#                             Mail  Location
# 0       smritiranjan65@gmail.com     Patna
# 1        tkumari930451@gmail.com     Patna
# 2      dksainiaggarwal@gmail.com  Dehradun
# 3      nirmalmukesh200@gmail.com  Dehradun
# 4                            NaN       NaN
# 5  ramakantprajapati11@gmail.com  Dehradun

# %%
pd.merge(df2,df3, on= 'Name')
# Out:
#                   Name  English  Hindi  Maths_x  Science_x  Social Science_x  \
# 0        Smriti Ranjan       85     83       93         91                94
# 1        Tannu kumari        90     75       78         73                75
# 2                Seema       93     98       78         89                94
# 3        Mukesh Nirmal       92     71       72         96                75
# 4                rohit       75     78       87         90                87
# 5             Ramakant       84     76       75         76                96
# 6  Vinod Kumar Sharma        75     96       74         81                71
# 7   Gulshan Kumar Ray        73     74       84         76                85
# 8  Ashutosh Kumar raj        89     70       80         97                95
#
#                             Mail  Location  Maths_y  Science_y  \
# 0       smritiranjan65@gmail.com     Patna       93       91.0
# 1        tkumari930451@gmail.com     Patna       78       73.0
# ...

# %%
pd.merge(df2, df3, how = 'inner')
# Out:
#             Name  English  Hindi  Maths  Science  Social Science  \
# 0  Smriti Ranjan       85     83     93       91              94
# 1  Tannu kumari        90     75     78       73              75
# 2          Seema       93     98     78       89              94
# 3  Mukesh Nirmal       92     71     72       96              75
# 4          rohit       75     78     87       90              87
# 5       Ramakant       84     76     75       76              96
#
#                             Mail  Location
# 0       smritiranjan65@gmail.com     Patna
# 1        tkumari930451@gmail.com     Patna
# 2      dksainiaggarwal@gmail.com  Dehradun
# 3      nirmalmukesh200@gmail.com  Dehradun
# 4                            NaN       NaN
# 5  ramakantprajapati11@gmail.com  Dehradun

# %%
pd.merge(df2,df3, how  ='right')
# Out:
#                   Name  English  Hindi  Maths  Science  Social Science  \
# 0        Smriti Ranjan     85.0   83.0     93     91.0            94.0
# 1        Tannu kumari      90.0   75.0     78     73.0            75.0
# 2                Seema     93.0   98.0     78     89.0            94.0
# 3        Mukesh Nirmal     92.0   71.0     72     96.0            75.0
# 4                rohit     75.0   78.0     87     90.0            87.0
# 5             Ramakant     84.0   76.0     75     76.0            96.0
# 6  Vinod Kumar Sharma       NaN    NaN     74      NaN             NaN
# 7   Gulshan Kumar Ray       NaN    NaN     83      NaN             NaN
# 8  Ashutosh Kumar raj       NaN    NaN     89      NaN             NaN
#
#                             Mail  Location
# 0       smritiranjan65@gmail.com     Patna
# 1        tkumari930451@gmail.com     Patna
# 2      dksainiaggarwal@gmail.com  Dehradun
# 3      nirmalmukesh200@gmail.com  Dehradun
# ...

# %%
pd.merge(df2,df3, how  ='left')
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science  \
# 0          Smriti Ranjan       85     83     93       91              94
# 1          Tannu kumari        90     75     78       73              75
# 2                  Seema       93     98     78       89              94
# 3          Mukesh Nirmal       92     71     72       96              75
# 4                  rohit       75     78     87       90              87
# 5               Ramakant       84     76     75       76              96
# 6    Vinod Kumar Sharma        75     96     74       81              71
# 7     Gulshan Kumar Ray        73     74     84       76              85
# 8    Ashutosh Kumar raj        89     70     80       97              95
# 9             Amit kumar       80     71     73       87              96
# 10          Astha sachan       77     71     77       95              72
# 11          Shail Kumari       95     97     80       92              92
# ...

# %%
df4 =pd.read_csv('m2.csv')
df4
# Out:
#                   Name                           Mail  Location  Maths  \
# 0        Smriti Ranjan       smritiranjan65@gmail.com     Patna     93
# 1        Tannu kumari         tkumari930451@gmail.com     Patna     78
# 2                Seema      dksainiaggarwal@gmail.com  Dehradun     78
# 3        Mukesh Nirmal      nirmalmukesh200@gmail.com  Dehradun     72
# 4                rohit                            NaN       NaN     87
# 5             Ramakant  ramakantprajapati11@gmail.com  Dehradun     75
# 6  Vinod Kumar Sharma     vinodsharma740860@gmail.com    Kanpur     74
# 7   Gulshan Kumar Ray         raygulshan960@gmail.com  Dehradun     83
# 8  Ashutosh Kumar raj        ashutoshraj822@gmail.com     Patna     89
#
#    Science  Social Science
# 0     91.0            94.0
# 1     73.0            75.0
# 2     89.0            94.0
# 3     96.0            75.0
# 4     90.0            87.0
# 5     76.0            96.0
# 6      NaN             NaN
# 7      NaN             NaN
# ...

# %%
pd.merge(df2,df4)
# Out:
#             Name  English  Hindi  Maths  Science  Social Science  \
# 0  Smriti Ranjan       85     83     93       91              94
# 1  Tannu kumari        90     75     78       73              75
# 2          Seema       93     98     78       89              94
# 3  Mukesh Nirmal       92     71     72       96              75
# 4          rohit       75     78     87       90              87
# 5       Ramakant       84     76     75       76              96
#
#                             Mail  Location
# 0       smritiranjan65@gmail.com     Patna
# 1        tkumari930451@gmail.com     Patna
# 2      dksainiaggarwal@gmail.com  Dehradun
# 3      nirmalmukesh200@gmail.com  Dehradun
# 4                            NaN       NaN
# 5  ramakantprajapati11@gmail.com  Dehradun

# %%
pd.merge(df2,df4, on ='Name')
# Out:
#                   Name  English  Hindi  Maths_x  Science_x  Social Science_x  \
# 0        Smriti Ranjan       85     83       93         91                94
# 1        Tannu kumari        90     75       78         73                75
# 2                Seema       93     98       78         89                94
# 3        Mukesh Nirmal       92     71       72         96                75
# 4                rohit       75     78       87         90                87
# 5             Ramakant       84     76       75         76                96
# 6  Vinod Kumar Sharma        75     96       74         81                71
# 7   Gulshan Kumar Ray        73     74       84         76                85
# 8  Ashutosh Kumar raj        89     70       80         97                95
#
#                             Mail  Location  Maths_y  Science_y  \
# 0       smritiranjan65@gmail.com     Patna       93       91.0
# 1        tkumari930451@gmail.com     Patna       78       73.0
# ...

# %%
pd.merge(df2,df4, how='inner')
# Out:
#             Name  English  Hindi  Maths  Science  Social Science  \
# 0  Smriti Ranjan       85     83     93       91              94
# 1  Tannu kumari        90     75     78       73              75
# 2          Seema       93     98     78       89              94
# 3  Mukesh Nirmal       92     71     72       96              75
# 4          rohit       75     78     87       90              87
# 5       Ramakant       84     76     75       76              96
#
#                             Mail  Location
# 0       smritiranjan65@gmail.com     Patna
# 1        tkumari930451@gmail.com     Patna
# 2      dksainiaggarwal@gmail.com  Dehradun
# 3      nirmalmukesh200@gmail.com  Dehradun
# 4                            NaN       NaN
# 5  ramakantprajapati11@gmail.com  Dehradun

# %%
pd.merge(df2,df4, how='left')
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science  \
# 0          Smriti Ranjan       85     83     93       91              94
# 1          Tannu kumari        90     75     78       73              75
# 2                  Seema       93     98     78       89              94
# 3          Mukesh Nirmal       92     71     72       96              75
# 4                  rohit       75     78     87       90              87
# 5               Ramakant       84     76     75       76              96
# 6    Vinod Kumar Sharma        75     96     74       81              71
# 7     Gulshan Kumar Ray        73     74     84       76              85
# 8    Ashutosh Kumar raj        89     70     80       97              95
# 9             Amit kumar       80     71     73       87              96
# 10          Astha sachan       77     71     77       95              72
# 11          Shail Kumari       95     97     80       92              92
# ...

# %%
pd.merge(df3,df4, how='right')
# Out:
#                   Name                           Mail  Location  Maths  \
# 0        Smriti Ranjan       smritiranjan65@gmail.com     Patna     93
# 1        Tannu kumari         tkumari930451@gmail.com     Patna     78
# 2                Seema      dksainiaggarwal@gmail.com  Dehradun     78
# 3        Mukesh Nirmal      nirmalmukesh200@gmail.com  Dehradun     72
# 4                rohit                            NaN       NaN     87
# 5             Ramakant  ramakantprajapati11@gmail.com  Dehradun     75
# 6  Vinod Kumar Sharma     vinodsharma740860@gmail.com    Kanpur     74
# 7   Gulshan Kumar Ray         raygulshan960@gmail.com  Dehradun     83
# 8  Ashutosh Kumar raj        ashutoshraj822@gmail.com     Patna     89
#
#    Science  Social Science
# 0     91.0            94.0
# 1     73.0            75.0
# 2     89.0            94.0
# 3     96.0            75.0
# 4     90.0            87.0
# 5     76.0            96.0
# 6      NaN             NaN
# 7      NaN             NaN
# ...

# %%
pd.merge(df3,df4, how='outer', indicator= True)
# Out:
#                   Name                           Mail  Location  Maths  \
# 0        Smriti Ranjan       smritiranjan65@gmail.com     Patna     93
# 1        Tannu kumari         tkumari930451@gmail.com     Patna     78
# 2                Seema      dksainiaggarwal@gmail.com  Dehradun     78
# 3        Mukesh Nirmal      nirmalmukesh200@gmail.com  Dehradun     72
# 4                rohit                            NaN       NaN     87
# 5             Ramakant  ramakantprajapati11@gmail.com  Dehradun     75
# 6  Vinod Kumar Sharma     vinodsharma740860@gmail.com    Kanpur     74
# 7   Gulshan Kumar Ray         raygulshan960@gmail.com  Dehradun     83
# 8  Ashutosh Kumar raj        ashutoshraj822@gmail.com     Patna     89
#
#    Science  Social Science _merge
# 0     91.0            94.0   both
# 1     73.0            75.0   both
# 2     89.0            94.0   both
# 3     96.0            75.0   both
# 4     90.0            87.0   both
# 5     76.0            96.0   both
# ...

# %%
pd.concat([df2,df3])
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science  \
# 0          Smriti Ranjan     85.0   83.0     93     91.0            94.0
# 1          Tannu kumari      90.0   75.0     78     73.0            75.0
# 2                  Seema     93.0   98.0     78     89.0            94.0
# 3          Mukesh Nirmal     92.0   71.0     72     96.0            75.0
# 4                  rohit     75.0   78.0     87     90.0            87.0
# 5               Ramakant     84.0   76.0     75     76.0            96.0
# 6    Vinod Kumar Sharma      75.0   96.0     74     81.0            71.0
# 7     Gulshan Kumar Ray      73.0   74.0     84     76.0            85.0
# 8    Ashutosh Kumar raj      89.0   70.0     80     97.0            95.0
# 9             Amit kumar     80.0   71.0     73     87.0            96.0
# 10          Astha sachan     77.0   71.0     77     95.0            72.0
# 11          Shail Kumari     95.0   97.0     80     92.0            92.0
# ...

# %%
pd.concat([df2,df3], axis =1)
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science  \
# 0          Smriti Ranjan       85     83     93       91              94
# 1          Tannu kumari        90     75     78       73              75
# 2                  Seema       93     98     78       89              94
# 3          Mukesh Nirmal       92     71     72       96              75
# 4                  rohit       75     78     87       90              87
# 5               Ramakant       84     76     75       76              96
# 6    Vinod Kumar Sharma        75     96     74       81              71
# 7     Gulshan Kumar Ray        73     74     84       76              85
# 8    Ashutosh Kumar raj        89     70     80       97              95
# 9             Amit kumar       80     71     73       87              96
# 10          Astha sachan       77     71     77       95              72
# 11          Shail Kumari       95     97     80       92              92
# ...

# %%
pd.concat([df2,df3] , axis=1,join ='inner',keys=['Details'])
# Out:
#                  Details
#                     Name English Hindi Maths Science Social Science
# 0          Smriti Ranjan      85    83    93      91             94
# 1          Tannu kumari       90    75    78      73             75
# 2                  Seema      93    98    78      89             94
# 3          Mukesh Nirmal      92    71    72      96             75
# 4                  rohit      75    78    87      90             87
# 5               Ramakant      84    76    75      76             96
# 6    Vinod Kumar Sharma       75    96    74      81             71
# 7     Gulshan Kumar Ray       73    74    84      76             85
# 8    Ashutosh Kumar raj       89    70    80      97             95
# 9             Amit kumar      80    71    73      87             96
# 10          Astha sachan      77    71    77      95             72
# 11          Shail Kumari      95    97    80      92             92
# ...

# %%
a1 =pd.concat([df2,df3])
a1
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science  \
# 0          Smriti Ranjan     85.0   83.0     93     91.0            94.0
# 1          Tannu kumari      90.0   75.0     78     73.0            75.0
# 2                  Seema     93.0   98.0     78     89.0            94.0
# 3          Mukesh Nirmal     92.0   71.0     72     96.0            75.0
# 4                  rohit     75.0   78.0     87     90.0            87.0
# 5               Ramakant     84.0   76.0     75     76.0            96.0
# 6    Vinod Kumar Sharma      75.0   96.0     74     81.0            71.0
# 7     Gulshan Kumar Ray      73.0   74.0     84     76.0            85.0
# 8    Ashutosh Kumar raj      89.0   70.0     80     97.0            95.0
# 9             Amit kumar     80.0   71.0     73     87.0            96.0
# 10          Astha sachan     77.0   71.0     77     95.0            72.0
# 11          Shail Kumari     95.0   97.0     80     92.0            92.0
# ...

# %%
a2 =a1.groupby('Name')
a2

# %%
a2.get_group('Seema')
# Out:
#     Name  English  Hindi  Maths  Science  Social Science  \
# 2  Seema     93.0   98.0     78     89.0            94.0
# 2  Seema      NaN    NaN     78     89.0            94.0
#
#                         Mail  Location
# 2                        NaN       NaN
# 2  dksainiaggarwal@gmail.com  Dehradun

# %%
a2.get_group('rohit')
# Out:
#     Name  English  Hindi  Maths  Science  Social Science Mail Location
# 4  rohit     75.0   78.0     87     90.0            87.0  NaN      NaN
# 4  rohit      NaN    NaN     87     90.0            87.0  NaN      NaN

# %%
a2.get_group('Ramakant')
# Out:
#        Name  English  Hindi  Maths  Science  Social Science  \
# 5  Ramakant     84.0   76.0     75     76.0            96.0
# 5  Ramakant      NaN    NaN     75     76.0            96.0
#
#                             Mail  Location
# 5                            NaN       NaN
# 5  ramakantprajapati11@gmail.com  Dehradun

# %%
for x in a2:
    print(x)
# Out:
# ('Amit kumar',          Name  English  Hindi  Maths  Science  Social Science Mail Location
# 9  Amit kumar     80.0   71.0     73     87.0            96.0  NaN      NaN)
# ('Annapurna Rawat',                Name  English  Hindi  Maths  Science  Social Science Mail  \
# 15  Annapurna Rawat     70.0   75.0     79     96.0            80.0  NaN
#
#    Location
# 15      NaN  )
# ('Ashutosh Kumar raj ',                   Name  English  Hindi  Maths  Science  Social Science  \
# 8  Ashutosh Kumar raj      89.0   70.0     80     97.0            95.0
# 8  Ashutosh Kumar raj       NaN    NaN     89      NaN             NaN
#
#                        Mail Location
# 8                       NaN      NaN
# 8  ashutoshraj822@gmail.com    Patna  )
# ('Astha sachan',             Name  English  Hindi  Maths  Science  Social Science Mail Location
# 10  Astha sachan     77.0   71.0     77     95.0            72.0  NaN      NaN)
# ...

# %%
for x ,y in a2:
    print(x)
    print(y)
# Out:
# Amit kumar
#          Name  English  Hindi  Maths  Science  Social Science Mail Location
# 9  Amit kumar     80.0   71.0     73     87.0            96.0  NaN      NaN
# Annapurna Rawat
#                Name  English  Hindi  Maths  Science  Social Science Mail  \
# 15  Annapurna Rawat     70.0   75.0     79     96.0            80.0  NaN
#
#    Location
# 15      NaN
# Ashutosh Kumar raj
#                   Name  English  Hindi  Maths  Science  Social Science  \
# 8  Ashutosh Kumar raj      89.0   70.0     80     97.0            95.0
# 8  Ashutosh Kumar raj       NaN    NaN     89      NaN             NaN
#
#                        Mail Location
# 8                       NaN      NaN
# 8  ashutoshraj822@gmail.com    Patna
# Astha sachan
#             Name  English  Hindi  Maths  Science  Social Science Mail Location
# 10  Astha sachan     77.0   71.0     77     95.0            72.0  NaN      NaN
# Gulshan Kumar Ray
# ...

# %%
a2 = a1.groupby('Maths')
a2

# %%
a2.get_group(78)
# Out:
#              Name  English  Hindi  Maths  Science  Social Science  \
# 1   Tannu kumari      90.0   75.0     78     73.0            75.0
# 2           Seema     93.0   98.0     78     89.0            94.0
# 17         Seema.     93.0   75.0     78     89.0            94.0
# 1   Tannu kumari       NaN    NaN     78     73.0            75.0
# 2           Seema      NaN    NaN     78     89.0            94.0
#
#                          Mail  Location
# 1                         NaN       NaN
# 2                         NaN       NaN
# 17                        NaN       NaN
# 1     tkumari930451@gmail.com     Patna
# 2   dksainiaggarwal@gmail.com  Dehradun

# %%
df2.join(df3, Isuffix='_12')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[169], line 1
# ----> 1 df2.join(df3, Isuffix='_12')
#
# TypeError: DataFrame.join() got an unexpected keyword argument 'Isuffix'

# %%
df2.join(df3, rsuffix='_1')
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science  \
# 0          Smriti Ranjan       85     83     93       91              94
# 1          Tannu kumari        90     75     78       73              75
# 2                  Seema       93     98     78       89              94
# 3          Mukesh Nirmal       92     71     72       96              75
# 4                  rohit       75     78     87       90              87
# 5               Ramakant       84     76     75       76              96
# 6    Vinod Kumar Sharma        75     96     74       81              71
# 7     Gulshan Kumar Ray        73     74     84       76              85
# 8    Ashutosh Kumar raj        89     70     80       97              95
# 9             Amit kumar       80     71     73       87              96
# 10          Astha sachan       77     71     77       95              72
# 11          Shail Kumari       95     97     80       92              92
# ...

# %%
# Data cleaning

# %%
import pandas as pd

# %%
df5 =pd.read_csv('marks1.csv')
df5
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science
# 0          Smriti Ranjan       85     83     93       91              94
# 1          Tannu kumari        90     75     78       73              75
# 2                  Seema       93     98     78       89              94
# 3          Mukesh Nirmal       92     71     72       96              75
# 4                  rohit       75     78     87       90              87
# 5               Ramakant       84     76     75       76              96
# 6    Vinod Kumar Sharma        75     96     74       81              71
# 7     Gulshan Kumar Ray        73     74     84       76              85
# 8    Ashutosh Kumar raj        89     70     80       97              95
# 9             Amit kumar       80     71     73       87              96
# 10          Astha sachan       77     71     77       95              72
# 11          Shail Kumari       95     97     80       92              92
# ...

# %%
df5.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20     True
# dtype: bool

# %%
df5.drop_duplicates(inplace= True)
df5
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science
# 0          Smriti Ranjan       85     83     93       91              94
# 1          Tannu kumari        90     75     78       73              75
# 2                  Seema       93     98     78       89              94
# 3          Mukesh Nirmal       92     71     72       96              75
# 4                  rohit       75     78     87       90              87
# 5               Ramakant       84     76     75       76              96
# 6    Vinod Kumar Sharma        75     96     74       81              71
# 7     Gulshan Kumar Ray        73     74     84       76              85
# 8    Ashutosh Kumar raj        89     70     80       97              95
# 9             Amit kumar       80     71     73       87              96
# 10          Astha sachan       77     71     77       95              72
# 11          Shail Kumari       95     97     80       92              92
# ...

# %%
df5
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science
# 0          Smriti Ranjan       85     83     93       91              94
# 1          Tannu kumari        90     75     78       73              75
# 2                  Seema       93     98     78       89              94
# 3          Mukesh Nirmal       92     71     72       96              75
# 4                  rohit       75     78     87       90              87
# 5               Ramakant       84     76     75       76              96
# 6    Vinod Kumar Sharma        75     96     74       81              71
# 7     Gulshan Kumar Ray        73     74     84       76              85
# 8    Ashutosh Kumar raj        89     70     80       97              95
# 9             Amit kumar       80     71     73       87              96
# 10          Astha sachan       77     71     77       95              72
# 11          Shail Kumari       95     97     80       92              92
# ...

# %%
df5.drop(columns = 'English', inplace=True)

# %%
df
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science
# 0          Smriti Ranjan       85     83     93       91              94
# 1          Tannu kumari        90     75     78       73              75
# 2                  Seema       93     98     78       89              94
# 3          Mukesh Nirmal       92     71     72       96              75
# 4                  rohit       75     78     87       90              87
# 5               Ramakant       84     76     75       76              96
# 6    Vinod Kumar Sharma        75     96     74       81              71
# 7     Gulshan Kumar Ray        73     74     84       76              85
# 8    Ashutosh Kumar raj        89     70     80       97              95
# 9             Amit kumar       80     71     73       87              96
# 10          Astha sachan       77     71     77       95              72
# 11          Shail Kumari       95     97     80       92              92
# ...

# %%
df5['Name'].str.strip('..')
# Out:
# 0            Smriti Ranjan
# 1            Tannu kumari
# 2                    Seema
# 3            Mukesh Nirmal
# 4                    rohit
# 5                 Ramakant
# 6      Vinod Kumar Sharma
# 7       Gulshan Kumar Ray
# 8      Ashutosh Kumar raj
# 9               Amit kumar
# 10            Astha sachan
# 11            Shail Kumari
# 12    Vaishnavi Kesherwani
# 13               Rahul Rai
# 14                  Trapti
# 15         Annapurna Rawat
# 16                   Pooja
# 17                   Seema
# 19    Vaishnavi Kesherwani
# Name: Name, dtype: object

# %%
df5
# Out:
#                     Name  Hindi  Maths  Science  Social Science
# 0          Smriti Ranjan     83     93       91              94
# 1          Tannu kumari      75     78       73              75
# 2                  Seema     98     78       89              94
# 3          Mukesh Nirmal     71     72       96              75
# 4                  rohit     78     87       90              87
# 5               Ramakant     76     75       76              96
# 6    Vinod Kumar Sharma      96     74       81              71
# 7     Gulshan Kumar Ray      74     84       76              85
# 8    Ashutosh Kumar raj      70     80       97              95
# 9             Amit kumar     71     73       87              96
# 10          Astha sachan     71     77       95              72
# 11          Shail Kumari     97     80       92              92
# 12  Vaishnavi Kesherwani     90     88       91              71
# 13             Rahul Rai     77     76       80              78
# ...

# %%
df5['Name'].str.rstrip('..')
# Out:
# 0            Smriti Ranjan
# 1            Tannu kumari
# 2                    Seema
# 3            Mukesh Nirmal
# 4                    rohit
# 5                 Ramakant
# 6      Vinod Kumar Sharma
# 7       Gulshan Kumar Ray
# 8      Ashutosh Kumar raj
# 9               Amit kumar
# 10            Astha sachan
# 11            Shail Kumari
# 12    Vaishnavi Kesherwani
# 13               Rahul Rai
# 14                  Trapti
# 15         Annapurna Rawat
# 16                   Pooja
# 17                   Seema
# 19    Vaishnavi Kesherwani
# Name: Name, dtype: object

# %%
df5['Name'].str.lstrip('..')
# Out:
# 0            Smriti Ranjan
# 1            Tannu kumari
# 2                    Seema
# 3            Mukesh Nirmal
# 4                    rohit
# 5                 Ramakant
# 6      Vinod Kumar Sharma
# 7       Gulshan Kumar Ray
# 8      Ashutosh Kumar raj
# 9               Amit kumar
# 10            Astha sachan
# 11            Shail Kumari
# 12    Vaishnavi Kesherwani
# 13               Rahul Rai
# 14                  Trapti
# 15         Annapurna Rawat
# 16                   Pooja
# 17                  Seema.
# 19    Vaishnavi Kesherwani
# Name: Name, dtype: object

# %%
df5
# Out:
#                     Name  Hindi  Maths  Science  Social Science
# 0          Smriti Ranjan     83     93       91              94
# 1          Tannu kumari      75     78       73              75
# 2                  Seema     98     78       89              94
# 3          Mukesh Nirmal     71     72       96              75
# 4                  rohit     78     87       90              87
# 5               Ramakant     76     75       76              96
# 6    Vinod Kumar Sharma      96     74       81              71
# 7     Gulshan Kumar Ray      74     84       76              85
# 8    Ashutosh Kumar raj      70     80       97              95
# 9             Amit kumar     71     73       87              96
# 10          Astha sachan     71     77       95              72
# 11          Shail Kumari     97     80       92              92
# 12  Vaishnavi Kesherwani     90     88       91              71
# 13             Rahul Rai     77     76       80              78
# ...

# %%
df5['Name'].str.strip('^A-Z')
# Out:
# 0            Smriti Ranjan
# 1            Tannu kumari
# 2                    Seema
# 3            Mukesh Nirmal
# 4                    rohit
# 5                 Ramakant
# 6      Vinod Kumar Sharma
# 7       Gulshan Kumar Ray
# 8       shutosh Kumar raj
# 9                mit kumar
# 10             stha sachan
# 11            Shail Kumari
# 12    Vaishnavi Kesherwani
# 13               Rahul Rai
# 14                  Trapti
# 15          nnapurna Rawat
# 16                   Pooja
# 17                  Seema.
# 19    Vaishnavi Kesherwani
# Name: Name, dtype: object

# %%
df5.isnull()
# Out:
#      Name  Hindi  Maths  Science  Social Science
# 0   False  False  False    False           False
# 1   False  False  False    False           False
# 2   False  False  False    False           False
# 3   False  False  False    False           False
# 4   False  False  False    False           False
# 5   False  False  False    False           False
# 6   False  False  False    False           False
# 7   False  False  False    False           False
# 8   False  False  False    False           False
# 9   False  False  False    False           False
# 10  False  False  False    False           False
# 11  False  False  False    False           False
# 12  False  False  False    False           False
# 13  False  False  False    False           False
# 14  False  False  False    False           False
# 15  False  False  False    False           False
# 16  False  False  False    False           False
# 17  False  False  False    False           False
# ...

# %%
df5.isnull().sum()
# Out:
# Name              0
# Hindi             0
# Maths             0
# Science           0
# Social Science    0
# dtype: int64

# %%
df= pd.read_csv('marks1.csv')
df
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science
# 0          Smriti Ranjan       85     83     93       91              94
# 1          Tannu kumari        90     75     78       73              75
# 2                  Seema       93     98     78       89              94
# 3          Mukesh Nirmal       92     71     72       96              75
# 4                  rohit       75     78     87       90              87
# 5               Ramakant       84     76     75       76              96
# 6    Vinod Kumar Sharma        75     96     74       81              71
# 7     Gulshan Kumar Ray        73     74     84       76              85
# 8    Ashutosh Kumar raj        89     70     80       97              95
# 9             Amit kumar       80     71     73       87              96
# 10          Astha sachan       77     71     77       95              72
# 11          Shail Kumari       95     97     80       92              92
# ...

# %%
df5.rename(columns ={'Name':'Students'}, inplace =True)
df5
# Out:
#                 Students  Hindi  Maths  Science  Social Science
# 0          Smriti Ranjan     83     93       91              94
# 1          Tannu kumari      75     78       73              75
# 2                  Seema     98     78       89              94
# 3          Mukesh Nirmal     71     72       96              75
# 4                  rohit     78     87       90              87
# 5               Ramakant     76     75       76              96
# 6    Vinod Kumar Sharma      96     74       81              71
# 7     Gulshan Kumar Ray      74     84       76              85
# 8    Ashutosh Kumar raj      70     80       97              95
# 9             Amit kumar     71     73       87              96
# 10          Astha sachan     71     77       95              72
# 11          Shail Kumari     97     80       92              92
# 12  Vaishnavi Kesherwani     90     88       91              71
# 13             Rahul Rai     77     76       80              78
# ...

# %%
df5['Total'] = df5['Hindi']+ df5['Science']+ df5['Social Science']
df5
# Out:
#                 Students  Hindi  Maths  Science  Social Science  Total
# 0          Smriti Ranjan     83     93       91              94    268
# 1          Tannu kumari      75     78       73              75    223
# 2                  Seema     98     78       89              94    281
# 3          Mukesh Nirmal     71     72       96              75    242
# 4                  rohit     78     87       90              87    255
# 5               Ramakant     76     75       76              96    248
# 6    Vinod Kumar Sharma      96     74       81              71    248
# 7     Gulshan Kumar Ray      74     84       76              85    235
# 8    Ashutosh Kumar raj      70     80       97              95    262
# 9             Amit kumar     71     73       87              96    254
# 10          Astha sachan     71     77       95              72    238
# 11          Shail Kumari     97     80       92              92    281
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Students        19 non-null     object
#  1   Hindi           19 non-null     int64
#  2   Maths           19 non-null     int64
#  3   Science         19 non-null     int64
#  4   Social Science  19 non-null     int64
#  5   Total           19 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.0+ KB

# %%
df5['Science'] =df5['Science'].str.replace("[A-Z a-z]","",regex=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[191], line 1
# ----> 1 df5['Science'] =df5['Science'].str.replace("[A-Z a-z]","",regex=True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
# ...

# %%
df5.describe()
# Out:
#            Hindi      Maths    Science  Social Science       Total
# count  19.000000  19.000000  19.000000       19.000000   19.000000
# mean   80.894737  80.157895  86.315789       83.631579  250.842105
# std     9.706211   6.193753  10.381889       11.061497   20.070053
# min    70.000000  72.000000  56.000000       65.000000  206.000000
# 25%    74.500000  75.500000  80.500000       73.500000  240.000000
# 50%    77.000000  78.000000  90.000000       85.000000  251.000000
# 75%    87.500000  85.500000  93.000000       94.000000  260.000000
# max    98.000000  93.000000  97.000000       98.000000  287.000000

# %%
df5 =pd.read_csv('marks1.csv')
df5
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science
# 0          Smriti Ranjan       85     83     93       91              94
# 1          Tannu kumari        90     75     78       73              75
# 2                  Seema       93     98     78       89              94
# 3          Mukesh Nirmal       92     71     72       96              75
# 4                  rohit       75     78     87       90              87
# 5               Ramakant       84     76     75       76              96
# 6    Vinod Kumar Sharma        75     96     74       81              71
# 7     Gulshan Kumar Ray        73     74     84       76              85
# 8    Ashutosh Kumar raj        89     70     80       97              95
# 9             Amit kumar       80     71     73       87              96
# 10          Astha sachan       77     71     77       95              72
# 11          Shail Kumari       95     97     80       92              92
# ...

# %%
df5.describe()
# Out:
#          English      Hindi      Maths    Science  Social Science
# count  21.000000  21.000000  21.000000  21.000000       21.000000
# mean   83.142857  81.476190  79.952381  86.285714       83.761905
# std     8.241879   9.907669   5.945386  10.030667       10.732683
# min    70.000000  70.000000  72.000000  56.000000       65.000000
# 25%    75.000000  75.000000  76.000000  80.000000       75.000000
# 50%    82.000000  77.000000  78.000000  90.000000       85.000000
# 75%    91.000000  90.000000  84.000000  92.000000       94.000000
# max    95.000000  98.000000  93.000000  97.000000       98.000000

# %%
mean_h =df5['Hindi'].mean()
mean_d =df5['Hindi'].median()
mean_h
mean_d
# Out:
# 77.0

# %%
mean_s=df5['Science'].mean()
mean_s
# Out:
# 86.28571428571429

# %%
mean_e=df5['English'].mean()
mean_e
# Out:
# 83.14285714285714

# %%
mean_ss=df5['Social Science'].mean()
mean_ss
# Out:
# 83.76190476190476

# %%
mean_h =df5['Hindi'].median()
mean_h
# Out:
# 77.0

# %%
mean_h =df5['Hindi'].mode()
mean_h
# Out:
# 0    71
# 1    75
# Name: Hindi, dtype: int64

# %%
df5['Science'].isnull().any()
# Out:
# False

# %%
df5['Science'].isnull().all()
# Out:
# False

# %%
df5['Science'].isna().any()
# Out:
# False

# %%
df5['Science'].isna().all()
# Out:
# False

# %%
mean_ss=df5['Social Science'].median()
mean_ss
# Out:
# 85.0

# %%
df5['Social Science'].median(median_ss, inplace =True)
df5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[206], line 1
# ----> 1 df5['Social Science'].median(median_ss, inplace =True)
#       2 df5
#
# NameError: name 'median_ss' is not defined

# %%
median_t =df5['Hindi'].median()
median_t
# Out:
# 77.0

# %%
df5.replace(to_replace=948,value=99)
# Out:
#                     Name  English  Hindi  Maths  Science  Social Science
# 0          Smriti Ranjan       85     83     93       91              94
# 1          Tannu kumari        90     75     78       73              75
# 2                  Seema       93     98     78       89              94
# 3          Mukesh Nirmal       92     71     72       96              75
# 4                  rohit       75     78     87       90              87
# 5               Ramakant       84     76     75       76              96
# 6    Vinod Kumar Sharma        75     96     74       81              71
# 7     Gulshan Kumar Ray        73     74     84       76              85
# 8    Ashutosh Kumar raj        89     70     80       97              95
# 9             Amit kumar       80     71     73       87              96
# 10          Astha sachan       77     71     77       95              72
# 11          Shail Kumari       95     97     80       92              92
# ...

# %%
df5['Name'].describe()
# Out:
# count            21
# unique           18
# top       Rahul Rai
# freq              2
# Name: Name, dtype: object

# %%
# matlib
import matplotlib.pyplot as plt
plt.figure(figsize=(4,3))
x =[1,2,3,4,5]
y =[60,20,80,96,80]
a ={'color':'red','size':20, 'font-family':'arial'}
#title
plt.title("Seema Report", fontsize =15, loc='left')
#lable
plt.xlabel('Class', fontsize =10, color='orange')
plt.ylabel('Markes', fontsize = 10,color='g')
# figsize (width, height)
plt.plot(x,y, color='g', marker ='<')
plt.plot(x,y, color='g', marker ='o')
plt.plot(x,y, color='g', marker ='*')
plt.plot(x,y, color='g', marker ='+')
plt.plot(x,y, color='g', marker ='d')
plt.plot(x,y, color='g', marker ='D')
plt.plot(x,y, color='g', marker =',')
plt.plot(x,y, color='g', marker ='p')
plt.plot(x,y, color='g', marker ='x')
plt.plot(x,y, color='g', marker ='X', linestyle="-.")
plt.grid()
plt.show()

# %%
plt.plot([2,3,4,5],[56,98,62,35])
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']
